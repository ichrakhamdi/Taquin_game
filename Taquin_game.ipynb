# %%
import numpy as np
import time

# %%
class node():
    def __init__(self,etat,parent,action,depth,step_cost,path_cost,heuristic_cost):
        self.etat = etat 
        self.parent = parent # node parent
        self.action = action # move up, left, down, right
        self.depth = depth # depth of the node in the tree
        self.step_cost = step_cost # g(n), the cost to take the step
        self.path_cost = path_cost # accumulated g(n), the cost to reach the current node
        self.heuristic_cost = heuristic_cost # h(n), cost to reach goal etat from the current node
        
        # nœud fils
        self.move_up = None 
        self.move_left = None
        self.move_down = None
        self.move_right = None
    
    # see if moving down is valid
    def try_move_down(self):
        # if not possible
        zero_index=[i[0] for i in np.where(self.etat==0)] 
        if zero_index[0] == 0:
            return False
        #if possible
        else:
            up_value = self.etat[zero_index[0]-1,zero_index[1]] # value of the upper carreau
            new_etat = self.etat.copy()
            new_etat[zero_index[0],zero_index[1]] = up_value
            new_etat[zero_index[0]-1,zero_index[1]] = 0
            return new_etat,up_value
        
    # see if moving right is valid
    def try_move_right(self):
      # if not possible
        zero_index=[i[0] for i in np.where(self.etat==0)] 
        if zero_index[1] == 0:
            return False
      # if possible
        else:
            left_value = self.etat[zero_index[0],zero_index[1]-1] # value of the left carreau
            new_etat = self.etat.copy()
            new_etat[zero_index[0],zero_index[1]] = left_value
            new_etat[zero_index[0],zero_index[1]-1] = 0
            return new_etat,left_value
        
    # see if moving up is valid
    def try_move_up(self):
        zero_index=[i[0] for i in np.where(self.etat==0)] 
        if zero_index[0] == 2:
            return False
        else:
            lower_value = self.etat[zero_index[0]+1,zero_index[1]] # value of the lower carreau
            new_etat = self.etat.copy()
            new_etat[zero_index[0],zero_index[1]] = lower_value
            new_etat[zero_index[0]+1,zero_index[1]] = 0
            return new_etat,lower_value
        
    # see if moving left is valid
    def try_move_left(self):
        zero_index=[i[0] for i in np.where(self.etat==0)] 
        if zero_index[1] == 2:
            return False
        else:
            right_value = self.etat[zero_index[0],zero_index[1]+1] # value of the right carreau
            new_etat = self.etat.copy()
            new_etat[zero_index[0],zero_index[1]] = right_value
            new_etat[zero_index[0],zero_index[1]+1] = 0
            return new_etat,right_value
    
    # return user specified heuristic cost
    def get_h_cost(self,new_etat,goal_etat,heuristic_function,path_cost,depth):
        if heuristic_function == 'num_misplaced':
            return self.h_misplaced_cost(new_etat,goal_etat)
    
    # return heuristic cost: number of misplaced carreaus(compare with final node ==> goal)
    def h_misplaced_cost(self,new_etat,goal_etat):
        cost = np.sum(new_etat != goal_etat)-1 # minus 1 to exclude the empty carreau
        if cost > 0:
            return cost
        else:
            return 0 # when all carreaus matches
    
   
        
    # solution path
    def print_path(self):
        # create FILO stacks to place the trace
        etat_trace = [self.etat]
        action_trace = [self.action]
        depth_trace = [self.depth]
        step_cost_trace = [self.step_cost]
        path_cost_trace = [self.path_cost]
        heuristic_cost_trace = [self.heuristic_cost]
        
        # add node information as tracing back up the tree
        while self.parent:
            self = self.parent

            etat_trace.append(self.etat)
            action_trace.append(self.action)
            depth_trace.append(self.depth)
            step_cost_trace.append(self.step_cost)
            path_cost_trace.append(self.path_cost)
            heuristic_cost_trace.append(self.heuristic_cost)

        # print out the path
        step_counter = 0
        while etat_trace:
            print ('step',step_counter)
            print (etat_trace.pop())
            print ('action=',action_trace.pop(),', depth=',str(depth_trace.pop()),\
            ', step cost=',str(step_cost_trace.pop()),', total_cost=',\
            str(path_cost_trace.pop() + heuristic_cost_trace.pop()),'\n')
            
            step_counter += 1
    def depth_first_search(self, goal_etat):
        start = time.time()
        
        pile = [self] # pile of found but unvisited nodes, Pile : first in last out FILO
        pile_num_nodes_popped = 0 # number of nodes popped off the pile, measuring time performance
        pile_max_length = 1 # max number of nodes in the pile, measuring space performance
        
        depth_pile = [0] # pile of node depth
        path_cost_pile = [0] # pile for path cost
        visited = set([]) # record visited etats
        
        while pile:
            # update maximum length of the pile
            if len(pile) > pile_max_length:
                pile_max_length = len(pile)
                
            current_node = pile.pop(0) # select and remove the first node in the pile
            pile_num_nodes_popped += 1 
            
            current_depth = depth_pile.pop(0) # select and remove the depth for current node
            current_path_cost = path_cost_pile.pop(0) # # select and remove the path cost for reaching current node
            visited.add(tuple(current_node.etat.reshape(1,9)[0])) # add etat, which is represented as a tuple
            
            # when the goal etat is found, trace back to the root node and print out the path
            if np.array_equal(current_node.etat,goal_etat):
                current_node.print_path()
                
                print ('Time performance:',str(pile_num_nodes_popped),'nodes popped off the pile.')
                print ('Space performance:', str(pile_max_length),'nodes in the pile at its max.')
                print ('Time spent: %0.2fs' % (time.time()-start))
                return True
            
            else:                
                # see if moving upper carreau down is a valid move
                if current_node.try_move_down():
                    new_etat,up_value = current_node.try_move_down()
                    # check if the resulting node is already visited
                    if tuple(new_etat.reshape(1,9)[0]) not in visited:
                        # create a new child node
                        current_node.move_down = node(etat=new_etat,parent=current_node,action='down',depth=current_depth+1,\
                                              step_cost=up_value,path_cost=current_path_cost+up_value,heuristic_cost=0)
                        pile.insert(0,current_node.move_down)
                        depth_pile.insert(0,current_depth+1)
                        path_cost_pile.insert(0,current_path_cost+up_value)
                    
                # see if moving left carreau to the right is a valid move
                if current_node.try_move_right():
                    new_etat,left_value = current_node.try_move_right()
                    # check if the resulting node is already visited
                    if tuple(new_etat.reshape(1,9)[0]) not in visited:
                        # create a new child node
                        current_node.move_right = node(etat=new_etat,parent=current_node,action='right',depth=current_depth+1,\
                                              step_cost=left_value,path_cost=current_path_cost+left_value,heuristic_cost=0)
                        pile.insert(0,current_node.move_right)
                        depth_pile.insert(0,current_depth+1)
                        path_cost_pile.insert(0,current_path_cost+left_value)
                 
                # see if moving lower carreau up is a valid move
                if current_node.try_move_up():
                    new_etat,lower_value = current_node.try_move_up()
                    # check if the resulting node is already visited
                    if tuple(new_etat.reshape(1,9)[0]) not in visited:
                        # create a new child node
                        current_node.move_up = node(etat=new_etat,parent=current_node,action='up',depth=current_depth+1,\
                                              step_cost=lower_value,path_cost=current_path_cost+lower_value,heuristic_cost=0)
                        pile.insert(0,current_node.move_up)
                        depth_pile.insert(0,current_depth+1)
                        path_cost_pile.insert(0,current_path_cost+lower_value)

                # see if moving right carreau to the left is a valid move
                if current_node.try_move_left():
                    new_etat,right_value = current_node.try_move_left()
                    # check if the resulting node is already visited
                    if tuple(new_etat.reshape(1,9)[0]) not in visited:
                        # create a new child node
                        current_node.move_left = node(etat=new_etat,parent=current_node,action='left',depth=current_depth+1,\
                                              step_cost=right_value,path_cost=current_path_cost+right_value,heuristic_cost=0)
                        pile.insert(0,current_node.move_left)
                        depth_pile.insert(0,current_depth+1)
                        path_cost_pile.insert(0,current_path_cost+right_value)     
    def best_first_search(self, goal_etat):
        start = time.time()
        
        filee= [(self,0)] # filee of (found but unvisited nodes, heuristic cost), ordered by heuristic cost
        filee_num_nodes_popped = 0 # number of nodes popped off the filee, measuring time performance
        filee_max_length = 1 # max number of nodes in the filee, measuring space performance
        
        depth_filee = [(0,0)] # filee of node depth, (depth, heuristic cost)
        path_cost_filee = [(0,0)] # filee for path cost, (path_cost, heuristic cost)
        visited = set([]) # record visited etats
        
        while filee:
            # sort filee based on heuristic cost, in ascending order
            filee = sorted(filee, key=lambda x: x[1])
            depth_filee = sorted(depth_filee, key=lambda x: x[1])
            path_cost_filee= sorted(path_cost_filee, key=lambda x: x[1])
            
            # update maximum length of the filee
            if len(filee) > filee_max_length:
                filee_max_length = len(filee)
                
            current_node = filee.pop(0)[0] # select and remove the first node in the filee
          
            
            filee_num_nodes_popped += 1 
            current_depth = depth_filee.pop(0)[0] # select and remove the depth for current node
            current_path_cost = path_cost_filee.pop(0)[0] # # select and remove the path cost for reaching current node
            visited.add(tuple(current_node.etat.reshape(1,9)[0])) # avoid repeated etat, which is represented as a tuple
            
            # when the goal etat is found, trace back to the root node and print out the path
            if np.array_equal(current_node.etat,goal_etat):
                current_node.print_path()
                
                print ('Time performance:',str(filee_num_nodes_popped),'nodes popped off the filee.')
                print ('Space performance:', str(filee_max_length),'nodes in the filee at its max.')
                print ('Time spent: %0.2fs' % (time.time()-start))
                return True
            
            else:     
                # see if moving upper carreau down is a valid move
                if current_node.try_move_down():
                    new_etat,up_value = current_node.try_move_down()
                    # check if the resulting node is already visited
                    if tuple(new_etat.reshape(1,9)[0]) not in visited:
                        # get heuristic cost
                        h_cost = self.h_misplaced_cost(new_etat,goal_etat)
                        # create a new child node
                        current_node.move_down = node(etat=new_etat,parent=current_node,action='down',depth=current_depth+1,\
                                              step_cost=up_value,path_cost=current_path_cost+up_value,heuristic_cost=h_cost)
                        filee.append((current_node.move_down,h_cost))
                        depth_filee.append((current_depth+1,h_cost))
                        path_cost_filee.append((current_path_cost+up_value,h_cost))
                    
                # see if moving left carreau to the right is a valid move
                if current_node.try_move_right():
                    new_etat,left_value = current_node.try_move_right()
                    # check if the resulting node is already visited
                    if tuple(new_etat.reshape(1,9)[0]) not in visited:
                        # get heuristic cost
                        h_cost = self.h_misplaced_cost(new_etat,goal_etat)
                        # create a new child node
                        current_node.move_right = node(etat=new_etat,parent=current_node,action='right',depth=current_depth+1,\
                                              step_cost=left_value,path_cost=current_path_cost+left_value,heuristic_cost=h_cost)
                        filee.append((current_node.move_right,h_cost))
                        depth_filee.append((current_depth+1,h_cost))
                        path_cost_filee.append((current_path_cost+left_value,h_cost))
                    
                # see if moving lower carreau up is a valid move
                if current_node.try_move_up():
                    new_etat,lower_value = current_node.try_move_up()
                    # check if the resulting node is already visited
                    if tuple(new_etat.reshape(1,9)[0]) not in visited:
                        # get heuristic cost
                        h_cost = self.h_misplaced_cost(new_etat,goal_etat)
                        # create a new child node
                        current_node.move_up = node(etat=new_etat,parent=current_node,action='up',depth=current_depth+1,\
                                              step_cost=lower_value,path_cost=current_path_cost+lower_value,heuristic_cost=h_cost)
                        filee.append((current_node.move_up,h_cost))
                        depth_filee.append((current_depth+1,h_cost))
                        path_cost_filee.append((current_path_cost+lower_value,h_cost))

                # see if moving right carreau to the left is a valid move
                if current_node.try_move_left():
                    new_etat,right_value = current_node.try_move_left()
                    # check if the resulting node is already visited
                    if tuple(new_etat.reshape(1,9)[0]) not in visited:
                        # get heuristic cost
                        h_cost = self.h_misplaced_cost(new_etat,goal_etat)
                        # create a new child node
                        current_node.move_left = node(etat=new_etat,parent=current_node,action='left',depth=current_depth+1,\
                                              step_cost=right_value,path_cost=current_path_cost+right_value,heuristic_cost=h_cost)
                        filee.append((current_node.move_left,h_cost))
                        depth_filee.append((current_depth+1,h_cost))
                        path_cost_filee.append((current_path_cost+right_value,h_cost))
            
    # search based on path cost + heuristic cost
    def a_star_search(self,goal_etat,heuristic_function):
        start = time.time()
        
        queue = [(self,0)] # queue of (found but unvisited nodes, path cost+heuristic cost), ordered by the second element
        queue_num_nodes_popped = 0 # number of nodes popped off the queue, measuring time performance
        queue_max_length = 1 # max number of nodes in the queue, measuring space performance
        
        depth_queue = [(0,0)] # queue of node depth, (depth, path_cost+heuristic cost)
        path_cost_queue = [(0,0)] # queue for path cost, (path_cost, path_cost+heuristic cost)
        visited = set([]) # record visited etats
        
        while queue:
            # sort queue based on path_cost+heuristic cost, in ascending order
            queue = sorted(queue, key=lambda x: x[1])
            depth_queue = sorted(depth_queue, key=lambda x: x[1])
            path_cost_queue = sorted(path_cost_queue, key=lambda x: x[1])
            
            # update maximum length of the queue
            if len(queue) > queue_max_length:
                queue_max_length = len(queue)
                
            current_node = queue.pop(0)[0] # select and remove the first node in the queue
           
            
            queue_num_nodes_popped += 1 
            current_depth = depth_queue.pop(0)[0] # select and remove the depth for current node
            current_path_cost = path_cost_queue.pop(0)[0] # # select and remove the path cost for reaching current node
            visited.add(tuple(current_node.etat.reshape(1,9)[0])) # avoid repeated etat, which is represented as a tuple
            
            # when the goal etat is found, trace back to the root node and print out the path
            if np.array_equal(current_node.etat,goal_etat):
                current_node.print_path()
                
                print ('Time performance:',str(queue_num_nodes_popped),'nodes popped off the queue.')
                print ('Space performance:', str(queue_max_length),'nodes in the queue at its max.')
                print ('Time spent: %0.2fs' % (time.time()-start))
                return True
            
            else:     
                # see if moving upper carreau down is a valid move
                if current_node.try_move_down():
                    new_etat,up_value = current_node.try_move_down()
                    # check if the resulting node is already visited
                    if tuple(new_etat.reshape(1,9)[0]) not in visited:
                        path_cost=current_path_cost+up_value
                        depth = current_depth+1
                        # get heuristic cost
                        h_cost = self.get_h_cost(new_etat,goal_etat,heuristic_function,path_cost,depth)
                        # create a new child node
                        total_cost = path_cost+h_cost
                        current_node.move_down = node(etat=new_etat,parent=current_node,action='down',depth=depth,\
                                              step_cost=up_value,path_cost=path_cost,heuristic_cost=h_cost)
                        queue.append((current_node.move_down, total_cost))
                        depth_queue.append((depth, total_cost))
                        path_cost_queue.append((path_cost, total_cost))
                    
                # see if moving left carreau to the right is a valid move
                if current_node.try_move_right():
                    new_etat,left_value = current_node.try_move_right()
                    # check if the resulting node is already visited
                    if tuple(new_etat.reshape(1,9)[0]) not in visited:
                        path_cost=current_path_cost+left_value
                        depth = current_depth+1
                        # get heuristic cost
                        h_cost = self.get_h_cost(new_etat,goal_etat,heuristic_function,path_cost,depth)
                        # create a new child node
                        #cours:f=g+h
                        total_cost = path_cost+h_cost
                        current_node.move_right = node(etat=new_etat,parent=current_node,action='right',depth=depth,\
                                              step_cost=left_value,path_cost=path_cost,heuristic_cost=h_cost)
                        queue.append((current_node.move_right, total_cost))
                        depth_queue.append((depth, total_cost))
                        path_cost_queue.append((path_cost, total_cost))
                    
                # see if moving lower carreau up is a valid move
                if current_node.try_move_up():
                    new_etat,lower_value = current_node.try_move_up()
                    # check if the resulting node is already visited
                    if tuple(new_etat.reshape(1,9)[0]) not in visited:
                        path_cost=current_path_cost+lower_value
                        depth = current_depth+1
                        # get heuristic cost
                        h_cost = self.get_h_cost(new_etat,goal_etat,heuristic_function,path_cost,depth)
                        # create a new child node
                        total_cost = path_cost+h_cost 
                        current_node.move_up = node(etat=new_etat,parent=current_node,action='up',depth=depth,\
                                              step_cost=lower_value,path_cost=path_cost,heuristic_cost=h_cost)
                        queue.append((current_node.move_up, total_cost))
                        depth_queue.append((depth, total_cost))
                        path_cost_queue.append((path_cost, total_cost))

                # see if moving right carreau to the left is a valid move
                if current_node.try_move_left():
                    new_etat,right_value = current_node.try_move_left()
                    # check if the resulting node is already visited
                    if tuple(new_etat.reshape(1,9)[0]) not in visited:
                        path_cost=current_path_cost+right_value
                        depth = current_depth+1
                        # get heuristic cost
                        h_cost = self.get_h_cost(new_etat,goal_etat,heuristic_function,path_cost,depth)
                        # create a new child node
                        total_cost = path_cost+h_cost
                        current_node.move_left = node(etat=new_etat,parent=current_node,action='left',depth=depth,\
                                              step_cost=right_value,path_cost=path_cost,heuristic_cost=h_cost)
                        queue.append((current_node.move_left, total_cost))
                        depth_queue.append((depth, total_cost))
                        path_cost_queue.append((path_cost, total_cost))

# %%
test = np.array([2,8,3,1,6,4,7,0,5]).reshape(3,3)
initial_etat= test
goal_etat = np.array([1,2,3,8,0,4,7,6,5]).reshape(3,3)
print (initial_etat,'\n')
print (goal_etat)
# Out:
# [[2 8 3]
#  [1 6 4]
#  [7 0 5]]
#
# [[1 2 3]
#  [8 0 4]
#  [7 6 5]]

# %%
root_node = node(etat=initial_etat,parent=None,action=None,depth=0,step_cost=0,path_cost=0,heuristic_cost=0)

# %%
root_node.depth_first_search(goal_etat)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# [[3 2 5]
#  [4 0 1]
#  [6 8 7]]
# action= right , depth= 31541 , step cost= 1 , total_cost= 142810
#
# step 31542
# [[3 2 5]
#  [4 8 1]
#  [6 0 7]]
# action= up , depth= 31542 , step cost= 8 , total_cost= 142818
#
# step 31543
# [[3 2 5]
#  [4 8 1]
#  [6 7 0]]
# action= left , depth= 31543 , step cost= 7 , total_cost= 142825
#
# step 31544
# [[3 2 5]
#  [4 8 0]
#  [6 7 1]]
# action= down , depth= 31544 , step cost= 1 , total_cost= 142826
#
# step 31545
# [[3 2 5]
#  [4 0 8]
#  [6 7 1]]
# action= right , depth= 31545 , step cost= 8 , total_cost= 142834
#
# step 31546
# [[3 2 5]
#  [0 4 8]
#  [6 7 1]]
# action= right , depth= 31546 , step cost= 4 , total_cost= 142838
#
# step 31547
# [[3 2 5]
#  [6 4 8]
#  [0 7 1]]
# action= up , depth= 31547 , step cost= 6 , total_cost= 142844
#
# step 31548
# [[3 2 5]
#  [6 4 8]
#  [7 0 1]]
# action= left , depth= 31548 , step cost= 7 , total_cost= 142851
#
# step 31549
# [[3 2 5]
#  [6 4 8]
#  [7 1 0]]
# action= left , depth= 31549 , step cost= 1 , total_cost= 142852
#
# step 31550
# [[3 2 5]
#  [6 4 0]
#  [7 1 8]]
# action= down , depth= 31550 , step cost= 8 , total_cost= 142860
#
# step 31551
# [[3 2 5]
#  [6 0 4]
#  [7 1 8]]
# action= right , depth= 31551 , step cost= 4 , total_cost= 142864
#
# step 31552
# [[3 2 5]
#  [6 1 4]
#  [7 0 8]]
# action= up , depth= 31552 , step cost= 1 , total_cost= 142865
#
# step 31553
# [[3 2 5]
#  [6 1 4]
#  [7 8 0]]
# action= left , depth= 31553 , step cost= 8 , total_cost= 142873
#
# step 31554
# [[3 2 5]
#  [6 1 0]
#  [7 8 4]]
# action= down , depth= 31554 , step cost= 4 , total_cost= 142877
#
# step 31555
# [[3 2 5]
#  [6 0 1]
#  [7 8 4]]
# action= right , depth= 31555 , step cost= 1 , total_cost= 142878
#
# step 31556
# [[3 2 5]
#  [6 8 1]
#  [7 0 4]]
# action= up , depth= 31556 , step cost= 8 , total_cost= 142886
#
# step 31557
# [[3 2 5]
#  [6 8 1]
#  [7 4 0]]
# action= left , depth= 31557 , step cost= 4 , total_cost= 142890
#
# step 31558
# [[3 2 5]
#  [6 8 0]
#  [7 4 1]]
# action= down , depth= 31558 , step cost= 1 , total_cost= 142891
#
# step 31559
# [[3 2 5]
#  [6 0 8]
#  [7 4 1]]
# action= right , depth= 31559 , step cost= 8 , total_cost= 142899
#
# step 31560
# [[3 2 5]
#  [0 6 8]
#  [7 4 1]]
# action= right , depth= 31560 , step cost= 6 , total_cost= 142905
#
# step 31561
# [[3 2 5]
#  [7 6 8]
#  [0 4 1]]
# action= up , depth= 31561 , step cost= 7 , total_cost= 142912
#
# step 31562
# [[3 2 5]
#  [7 6 8]
#  [4 0 1]]
# action= left , depth= 31562 , step cost= 4 , total_cost= 142916
#
# step 31563
# [[3 2 5]
#  [7 6 8]
#  [4 1 0]]
# action= left , depth= 31563 , step cost= 1 , total_cost= 142917
#
# step 31564
# [[3 2 5]
#  [7 6 0]
#  [4 1 8]]
# action= down , depth= 31564 , step cost= 8 , total_cost= 142925
#
# step 31565
# [[3 2 5]
#  [7 0 6]
#  [4 1 8]]
# action= right , depth= 31565 , step cost= 6 , total_cost= 142931
#
# step 31566
# [[3 2 5]
#  [7 1 6]
#  [4 0 8]]
# action= up , depth= 31566 , step cost= 1 , total_cost= 142932
#
# step 31567
# [[3 2 5]
#  [7 1 6]
#  [4 8 0]]
# action= left , depth= 31567 , step cost= 8 , total_cost= 142940
#
# step 31568
# [[3 2 5]
#  [7 1 0]
#  [4 8 6]]
# action= down , depth= 31568 , step cost= 6 , total_cost= 142946
#
# step 31569
# [[3 2 5]
#  [7 0 1]
#  [4 8 6]]
# action= right , depth= 31569 , step cost= 1 , total_cost= 142947
#
# step 31570
# [[3 2 5]
#  [0 7 1]
#  [4 8 6]]
# action= right , depth= 31570 , step cost= 7 , total_cost= 142954
#
# step 31571
# [[3 2 5]
#  [4 7 1]
#  [0 8 6]]
# action= up , depth= 31571 , step cost= 4 , total_cost= 142958
#
# step 31572
# [[3 2 5]
#  [4 7 1]
#  [8 0 6]]
# action= left , depth= 31572 , step cost= 8 , total_cost= 142966
#
# step 31573
# [[3 2 5]
#  [4 7 1]
#  [8 6 0]]
# action= left , depth= 31573 , step cost= 6 , total_cost= 142972
#
# step 31574
# [[3 2 5]
#  [4 7 0]
#  [8 6 1]]
# action= down , depth= 31574 , step cost= 1 , total_cost= 142973
#
# step 31575
# [[3 2 5]
#  [4 0 7]
#  [8 6 1]]
# action= right , depth= 31575 , step cost= 7 , total_cost= 142980
#
# step 31576
# [[3 2 5]
#  [4 6 7]
#  [8 0 1]]
# action= up , depth= 31576 , step cost= 6 , total_cost= 142986
#
# step 31577
# [[3 2 5]
#  [4 6 7]
#  [8 1 0]]
# action= left , depth= 31577 , step cost= 1 , total_cost= 142987
#
# step 31578
# [[3 2 5]
#  [4 6 0]
#  [8 1 7]]
# action= down , depth= 31578 , step cost= 7 , total_cost= 142994
#
# step 31579
# [[3 2 5]
#  [4 0 6]
#  [8 1 7]]
# action= right , depth= 31579 , step cost= 6 , total_cost= 143000
#
# step 31580
# [[3 2 5]
#  [4 1 6]
#  [8 0 7]]
# action= up , depth= 31580 , step cost= 1 , total_cost= 143001
#
# step 31581
# [[3 2 5]
#  [4 1 6]
#  [8 7 0]]
# action= left , depth= 31581 , step cost= 7 , total_cost= 143008
#
# step 31582
# [[3 2 5]
#  [4 1 0]
#  [8 7 6]]
# action= down , depth= 31582 , step cost= 6 , total_cost= 143014
#
# step 31583
# [[3 2 5]
#  [4 0 1]
#  [8 7 6]]
# action= right , depth= 31583 , step cost= 1 , total_cost= 143015
#
# step 31584
# [[3 2 5]
#  [0 4 1]
#  [8 7 6]]
# action= right , depth= 31584 , step cost= 4 , total_cost= 143019
#
# step 31585
# [[3 2 5]
#  [8 4 1]
#  [0 7 6]]
# action= up , depth= 31585 , step cost= 8 , total_cost= 143027
#
# step 31586
# [[3 2 5]
#  [8 4 1]
#  [7 0 6]]
# action= left , depth= 31586 , step cost= 7 , total_cost= 143034
#
# step 31587
# [[3 2 5]
#  [8 4 1]
#  [7 6 0]]
# action= left , depth= 31587 , step cost= 6 , total_cost= 143040
#
# step 31588
# [[3 2 5]
#  [8 4 0]
#  [7 6 1]]
# action= down , depth= 31588 , step cost= 1 , total_cost= 143041
#
# step 31589
# [[3 2 5]
#  [8 0 4]
#  [7 6 1]]
# action= right , depth= 31589 , step cost= 4 , total_cost= 143045
#
# step 31590
# [[3 2 5]
#  [8 6 4]
#  [7 0 1]]
# action= up , depth= 31590 , step cost= 6 , total_cost= 143051
#
# step 31591
# [[3 2 5]
#  [8 6 4]
#  [7 1 0]]
# action= left , depth= 31591 , step cost= 1 , total_cost= 143052
#
# step 31592
# [[3 2 5]
#  [8 6 0]
#  [7 1 4]]
# action= down , depth= 31592 , step cost= 4 , total_cost= 143056
#
# step 31593
# [[3 2 5]
#  [8 0 6]
#  [7 1 4]]
# action= right , depth= 31593 , step cost= 6 , total_cost= 143062
#
# step 31594
# [[3 2 5]
#  [0 8 6]
#  [7 1 4]]
# action= right , depth= 31594 , step cost= 8 , total_cost= 143070
#
# step 31595
# [[3 2 5]
#  [7 8 6]
#  [0 1 4]]
# action= up , depth= 31595 , step cost= 7 , total_cost= 143077
#
# step 31596
# [[3 2 5]
#  [7 8 6]
#  [1 0 4]]
# action= left , depth= 31596 , step cost= 1 , total_cost= 143078
#
# step 31597
# [[3 2 5]
#  [7 8 6]
#  [1 4 0]]
# action= left , depth= 31597 , step cost= 4 , total_cost= 143082
#
# step 31598
# [[3 2 5]
#  [7 8 0]
#  [1 4 6]]
# action= down , depth= 31598 , step cost= 6 , total_cost= 143088
#
# step 31599
# [[3 2 5]
#  [7 0 8]
#  [1 4 6]]
# action= right , depth= 31599 , step cost= 8 , total_cost= 143096
#
# step 31600
# [[3 2 5]
#  [7 4 8]
#  [1 0 6]]
# action= up , depth= 31600 , step cost= 4 , total_cost= 143100
#
# step 31601
# [[3 2 5]
#  [7 4 8]
#  [1 6 0]]
# action= left , depth= 31601 , step cost= 6 , total_cost= 143106
#
# step 31602
# [[3 2 5]
#  [7 4 0]
#  [1 6 8]]
# action= down , depth= 31602 , step cost= 8 , total_cost= 143114
#
# step 31603
# [[3 2 5]
#  [7 0 4]
#  [1 6 8]]
# action= right , depth= 31603 , step cost= 4 , total_cost= 143118
#
# step 31604
# [[3 2 5]
#  [7 6 4]
#  [1 0 8]]
# action= up , depth= 31604 , step cost= 6 , total_cost= 143124
#
# step 31605
# [[3 2 5]
#  [7 6 4]
#  [1 8 0]]
# action= left , depth= 31605 , step cost= 8 , total_cost= 143132
#
# step 31606
# [[3 2 5]
#  [7 6 0]
#  [1 8 4]]
# action= down , depth= 31606 , step cost= 4 , total_cost= 143136
#
# step 31607
# [[3 2 5]
#  [7 0 6]
#  [1 8 4]]
# action= right , depth= 31607 , step cost= 6 , total_cost= 143142
#
# step 31608
# [[3 2 5]
#  [0 7 6]
#  [1 8 4]]
# action= right , depth= 31608 , step cost= 7 , total_cost= 143149
#
# step 31609
# [[0 2 5]
#  [3 7 6]
#  [1 8 4]]
# action= down , depth= 31609 , step cost= 3 , total_cost= 143152
#
# step 31610
# [[2 0 5]
#  [3 7 6]
#  [1 8 4]]
# action= left , depth= 31610 , step cost= 2 , total_cost= 143154
#
# step 31611
# [[2 7 5]
#  [3 0 6]
#  [1 8 4]]
# action= up , depth= 31611 , step cost= 7 , total_cost= 143161
#
# step 31612
# [[2 7 5]
#  [3 6 0]
#  [1 8 4]]
# action= left , depth= 31612 , step cost= 6 , total_cost= 143167
#
# step 31613
# [[2 7 5]
#  [3 6 4]
#  [1 8 0]]
# action= up , depth= 31613 , step cost= 4 , total_cost= 143171
#
# step 31614
# [[2 7 5]
#  [3 6 4]
#  [1 0 8]]
# action= right , depth= 31614 , step cost= 8 , total_cost= 143179
#
# step 31615
# [[2 7 5]
#  [3 6 4]
#  [0 1 8]]
# action= right , depth= 31615 , step cost= 1 , total_cost= 143180
#
# step 31616
# [[2 7 5]
#  [0 6 4]
#  [3 1 8]]
# action= down , depth= 31616 , step cost= 3 , total_cost= 143183
#
# step 31617
# [[0 7 5]
#  [2 6 4]
#  [3 1 8]]
# action= down , depth= 31617 , step cost= 2 , total_cost= 143185
#
# step 31618
# [[7 0 5]
#  [2 6 4]
#  [3 1 8]]
# action= left , depth= 31618 , step cost= 7 , total_cost= 143192
#
# step 31619
# [[7 5 0]
#  [2 6 4]
#  [3 1 8]]
# action= left , depth= 31619 , step cost= 5 , total_cost= 143197
#
# step 31620
# [[7 5 4]
#  [2 6 0]
#  [3 1 8]]
# action= up , depth= 31620 , step cost= 4 , total_cost= 143201
#
# step 31621
# [[7 5 4]
#  [2 6 8]
#  [3 1 0]]
# action= up , depth= 31621 , step cost= 8 , total_cost= 143209
#
# step 31622
# [[7 5 4]
#  [2 6 8]
#  [3 0 1]]
# action= right , depth= 31622 , step cost= 1 , total_cost= 143210
#
# step 31623
# [[7 5 4]
#  [2 6 8]
#  [0 3 1]]
# action= right , depth= 31623 , step cost= 3 , total_cost= 143213
#
# step 31624
# [[7 5 4]
#  [0 6 8]
#  [2 3 1]]
# action= down , depth= 31624 , step cost= 2 , total_cost= 143215
#
# step 31625
# [[7 5 4]
#  [6 0 8]
#  [2 3 1]]
# action= left , depth= 31625 , step cost= 6 , total_cost= 143221
#
# step 31626
# [[7 5 4]
#  [6 8 0]
#  [2 3 1]]
# action= left , depth= 31626 , step cost= 8 , total_cost= 143229
#
# step 31627
# [[7 5 4]
#  [6 8 1]
#  [2 3 0]]
# action= up , depth= 31627 , step cost= 1 , total_cost= 143230
#
# step 31628
# [[7 5 4]
#  [6 8 1]
#  [2 0 3]]
# action= right , depth= 31628 , step cost= 3 , total_cost= 143233
#
# step 31629
# [[7 5 4]
#  [6 8 1]
#  [0 2 3]]
# action= right , depth= 31629 , step cost= 2 , total_cost= 143235
#
# step 31630
# [[7 5 4]
#  [0 8 1]
#  [6 2 3]]
# action= down , depth= 31630 , step cost= 6 , total_cost= 143241
#
# step 31631
# [[7 5 4]
#  [8 0 1]
#  [6 2 3]]
# action= left , depth= 31631 , step cost= 8 , total_cost= 143249
#
# step 31632
# [[7 5 4]
#  [8 1 0]
#  [6 2 3]]
# action= left , depth= 31632 , step cost= 1 , total_cost= 143250
#
# step 31633
# [[7 5 4]
#  [8 1 3]
#  [6 2 0]]
# action= up , depth= 31633 , step cost= 3 , total_cost= 143253
#
# step 31634
# [[7 5 4]
#  [8 1 3]
#  [6 0 2]]
# action= right , depth= 31634 , step cost= 2 , total_cost= 143255
#
# step 31635
# [[7 5 4]
#  [8 1 3]
#  [0 6 2]]
# action= right , depth= 31635 , step cost= 6 , total_cost= 143261
#
# step 31636
# [[7 5 4]
#  [0 1 3]
#  [8 6 2]]
# action= down , depth= 31636 , step cost= 8 , total_cost= 143269
#
# step 31637
# [[7 5 4]
#  [1 0 3]
#  [8 6 2]]
# action= left , depth= 31637 , step cost= 1 , total_cost= 143270
#
# step 31638
# [[7 5 4]
#  [1 3 0]
#  [8 6 2]]
# action= left , depth= 31638 , step cost= 3 , total_cost= 143273
#
# step 31639
# [[7 5 4]
#  [1 3 2]
#  [8 6 0]]
# action= up , depth= 31639 , step cost= 2 , total_cost= 143275
#
# step 31640
# [[7 5 4]
#  [1 3 2]
#  [8 0 6]]
# action= right , depth= 31640 , step cost= 6 , total_cost= 143281
#
# step 31641
# [[7 5 4]
#  [1 3 2]
#  [0 8 6]]
# action= right , depth= 31641 , step cost= 8 , total_cost= 143289
#
# step 31642
# [[7 5 4]
#  [0 3 2]
#  [1 8 6]]
# action= down , depth= 31642 , step cost= 1 , total_cost= 143290
#
# step 31643
# [[0 5 4]
#  [7 3 2]
#  [1 8 6]]
# action= down , depth= 31643 , step cost= 7 , total_cost= 143297
#
# step 31644
# [[5 0 4]
#  [7 3 2]
#  [1 8 6]]
# action= left , depth= 31644 , step cost= 5 , total_cost= 143302
#
# step 31645
# [[5 4 0]
#  [7 3 2]
#  [1 8 6]]
# action= left , depth= 31645 , step cost= 4 , total_cost= 143306
#
# step 31646
# [[5 4 2]
#  [7 3 0]
#  [1 8 6]]
# action= up , depth= 31646 , step cost= 2 , total_cost= 143308
#
# step 31647
# [[5 4 2]
#  [7 3 6]
#  [1 8 0]]
# action= up , depth= 31647 , step cost= 6 , total_cost= 143314
#
# step 31648
# [[5 4 2]
#  [7 3 6]
#  [1 0 8]]
# action= right , depth= 31648 , step cost= 8 , total_cost= 143322
#
# step 31649
# [[5 4 2]
#  [7 3 6]
#  [0 1 8]]
# action= right , depth= 31649 , step cost= 1 , total_cost= 143323
#
# step 31650
# [[5 4 2]
#  [0 3 6]
#  [7 1 8]]
# action= down , depth= 31650 , step cost= 7 , total_cost= 143330
#
# step 31651
# [[5 4 2]
#  [3 0 6]
#  [7 1 8]]
# action= left , depth= 31651 , step cost= 3 , total_cost= 143333
#
# step 31652
# [[5 4 2]
#  [3 6 0]
#  [7 1 8]]
# action= left , depth= 31652 , step cost= 6 , total_cost= 143339
#
# step 31653
# [[5 4 2]
#  [3 6 8]
#  [7 1 0]]
# action= up , depth= 31653 , step cost= 8 , total_cost= 143347
#
# step 31654
# [[5 4 2]
#  [3 6 8]
#  [7 0 1]]
# action= right , depth= 31654 , step cost= 1 , total_cost= 143348
#
# step 31655
# [[5 4 2]
#  [3 6 8]
#  [0 7 1]]
# action= right , depth= 31655 , step cost= 7 , total_cost= 143355
#
# step 31656
# [[5 4 2]
#  [0 6 8]
#  [3 7 1]]
# action= down , depth= 31656 , step cost= 3 , total_cost= 143358
#
# step 31657
# [[5 4 2]
#  [6 0 8]
#  [3 7 1]]
# action= left , depth= 31657 , step cost= 6 , total_cost= 143364
#
# step 31658
# [[5 4 2]
#  [6 8 0]
#  [3 7 1]]
# action= left , depth= 31658 , step cost= 8 , total_cost= 143372
#
# step 31659
# [[5 4 2]
#  [6 8 1]
#  [3 7 0]]
# action= up , depth= 31659 , step cost= 1 , total_cost= 143373
#
# step 31660
# [[5 4 2]
#  [6 8 1]
#  [3 0 7]]
# action= right , depth= 31660 , step cost= 7 , total_cost= 143380
#
# step 31661
# [[5 4 2]
#  [6 8 1]
#  [0 3 7]]
# action= right , depth= 31661 , step cost= 3 , total_cost= 143383
#
# step 31662
# [[5 4 2]
#  [0 8 1]
#  [6 3 7]]
# action= down , depth= 31662 , step cost= 6 , total_cost= 143389
#
# step 31663
# [[5 4 2]
#  [8 0 1]
#  [6 3 7]]
# action= left , depth= 31663 , step cost= 8 , total_cost= 143397
#
# step 31664
# [[5 4 2]
#  [8 1 0]
#  [6 3 7]]
# action= left , depth= 31664 , step cost= 1 , total_cost= 143398
#
# step 31665
# [[5 4 2]
#  [8 1 7]
#  [6 3 0]]
# action= up , depth= 31665 , step cost= 7 , total_cost= 143405
#
# step 31666
# [[5 4 2]
#  [8 1 7]
#  [6 0 3]]
# action= right , depth= 31666 , step cost= 3 , total_cost= 143408
#
# step 31667
# [[5 4 2]
#  [8 1 7]
#  [0 6 3]]
# action= right , depth= 31667 , step cost= 6 , total_cost= 143414
#
# step 31668
# [[5 4 2]
#  [0 1 7]
#  [8 6 3]]
# action= down , depth= 31668 , step cost= 8 , total_cost= 143422
#
# step 31669
# [[5 4 2]
#  [1 0 7]
#  [8 6 3]]
# action= left , depth= 31669 , step cost= 1 , total_cost= 143423
#
# step 31670
# [[5 4 2]
#  [1 7 0]
#  [8 6 3]]
# action= left , depth= 31670 , step cost= 7 , total_cost= 143430
#
# step 31671
# [[5 4 2]
#  [1 7 3]
#  [8 6 0]]
# action= up , depth= 31671 , step cost= 3 , total_cost= 143433
#
# step 31672
# [[5 4 2]
#  [1 7 3]
#  [8 0 6]]
# action= right , depth= 31672 , step cost= 6 , total_cost= 143439
#
# step 31673
# [[5 4 2]
#  [1 7 3]
#  [0 8 6]]
# action= right , depth= 31673 , step cost= 8 , total_cost= 143447
#
# step 31674
# [[5 4 2]
#  [0 7 3]
#  [1 8 6]]
# action= down , depth= 31674 , step cost= 1 , total_cost= 143448
#
# step 31675
# [[5 4 2]
#  [7 0 3]
#  [1 8 6]]
# action= left , depth= 31675 , step cost= 7 , total_cost= 143455
#
# step 31676
# [[5 4 2]
#  [7 8 3]
#  [1 0 6]]
# action= up , depth= 31676 , step cost= 8 , total_cost= 143463
#
# step 31677
# [[5 4 2]
#  [7 8 3]
#  [1 6 0]]
# action= left , depth= 31677 , step cost= 6 , total_cost= 143469
#
# step 31678
# [[5 4 2]
#  [7 8 0]
#  [1 6 3]]
# action= down , depth= 31678 , step cost= 3 , total_cost= 143472
#
# step 31679
# [[5 4 2]
#  [7 0 8]
#  [1 6 3]]
# action= right , depth= 31679 , step cost= 8 , total_cost= 143480
#
# step 31680
# [[5 4 2]
#  [7 6 8]
#  [1 0 3]]
# action= up , depth= 31680 , step cost= 6 , total_cost= 143486
#
# step 31681
# [[5 4 2]
#  [7 6 8]
#  [1 3 0]]
# action= left , depth= 31681 , step cost= 3 , total_cost= 143489
#
# step 31682
# [[5 4 2]
#  [7 6 0]
#  [1 3 8]]
# action= down , depth= 31682 , step cost= 8 , total_cost= 143497
#
# step 31683
# [[5 4 2]
#  [7 0 6]
#  [1 3 8]]
# action= right , depth= 31683 , step cost= 6 , total_cost= 143503
#
# step 31684
# [[5 4 2]
#  [0 7 6]
#  [1 3 8]]
# action= right , depth= 31684 , step cost= 7 , total_cost= 143510
#
# step 31685
# [[5 4 2]
#  [1 7 6]
#  [0 3 8]]
# action= up , depth= 31685 , step cost= 1 , total_cost= 143511
#
# step 31686
# [[5 4 2]
#  [1 7 6]
#  [3 0 8]]
# action= left , depth= 31686 , step cost= 3 , total_cost= 143514
#
# step 31687
# [[5 4 2]
#  [1 7 6]
#  [3 8 0]]
# action= left , depth= 31687 , step cost= 8 , total_cost= 143522
#
# step 31688
# [[5 4 2]
#  [1 7 0]
#  [3 8 6]]
# action= down , depth= 31688 , step cost= 6 , total_cost= 143528
#
# step 31689
# [[5 4 2]
#  [1 0 7]
#  [3 8 6]]
# action= right , depth= 31689 , step cost= 7 , total_cost= 143535
#
# step 31690
# [[5 4 2]
#  [1 8 7]
#  [3 0 6]]
# action= up , depth= 31690 , step cost= 8 , total_cost= 143543
#
# step 31691
# [[5 4 2]
#  [1 8 7]
#  [3 6 0]]
# action= left , depth= 31691 , step cost= 6 , total_cost= 143549
#
# step 31692
# [[5 4 2]
#  [1 8 0]
#  [3 6 7]]
# action= down , depth= 31692 , step cost= 7 , total_cost= 143556
#
# step 31693
# [[5 4 2]
#  [1 0 8]
#  [3 6 7]]
# action= right , depth= 31693 , step cost= 8 , total_cost= 143564
#
# step 31694
# [[5 4 2]
#  [1 6 8]
#  [3 0 7]]
# action= up , depth= 31694 , step cost= 6 , total_cost= 143570
#
# step 31695
# [[5 4 2]
#  [1 6 8]
#  [3 7 0]]
# action= left , depth= 31695 , step cost= 7 , total_cost= 143577
#
# step 31696
# [[5 4 2]
#  [1 6 0]
#  [3 7 8]]
# action= down , depth= 31696 , step cost= 8 , total_cost= 143585
#
# step 31697
# [[5 4 2]
#  [1 0 6]
#  [3 7 8]]
# action= right , depth= 31697 , step cost= 6 , total_cost= 143591
#
# step 31698
# [[5 4 2]
#  [0 1 6]
#  [3 7 8]]
# action= right , depth= 31698 , step cost= 1 , total_cost= 143592
#
# step 31699
# [[5 4 2]
#  [3 1 6]
#  [0 7 8]]
# action= up , depth= 31699 , step cost= 3 , total_cost= 143595
#
# step 31700
# [[5 4 2]
#  [3 1 6]
#  [7 0 8]]
# action= left , depth= 31700 , step cost= 7 , total_cost= 143602
#
# step 31701
# [[5 4 2]
#  [3 1 6]
#  [7 8 0]]
# action= left , depth= 31701 , step cost= 8 , total_cost= 143610
#
# step 31702
# [[5 4 2]
#  [3 1 0]
#  [7 8 6]]
# action= down , depth= 31702 , step cost= 6 , total_cost= 143616
#
# step 31703
# [[5 4 2]
#  [3 0 1]
#  [7 8 6]]
# action= right , depth= 31703 , step cost= 1 , total_cost= 143617
#
# step 31704
# [[5 4 2]
#  [3 8 1]
#  [7 0 6]]
# action= up , depth= 31704 , step cost= 8 , total_cost= 143625
#
# step 31705
# [[5 4 2]
#  [3 8 1]
#  [7 6 0]]
# action= left , depth= 31705 , step cost= 6 , total_cost= 143631
#
# step 31706
# [[5 4 2]
#  [3 8 0]
#  [7 6 1]]
# action= down , depth= 31706 , step cost= 1 , total_cost= 143632
#
# step 31707
# [[5 4 2]
#  [3 0 8]
#  [7 6 1]]
# action= right , depth= 31707 , step cost= 8 , total_cost= 143640
#
# step 31708
# [[5 4 2]
#  [0 3 8]
#  [7 6 1]]
# action= right , depth= 31708 , step cost= 3 , total_cost= 143643
#
# step 31709
# [[5 4 2]
#  [7 3 8]
#  [0 6 1]]
# action= up , depth= 31709 , step cost= 7 , total_cost= 143650
#
# step 31710
# [[5 4 2]
#  [7 3 8]
#  [6 0 1]]
# action= left , depth= 31710 , step cost= 6 , total_cost= 143656
#
# step 31711
# [[5 4 2]
#  [7 3 8]
#  [6 1 0]]
# action= left , depth= 31711 , step cost= 1 , total_cost= 143657
#
# step 31712
# [[5 4 2]
#  [7 3 0]
#  [6 1 8]]
# action= down , depth= 31712 , step cost= 8 , total_cost= 143665
#
# step 31713
# [[5 4 2]
#  [7 0 3]
#  [6 1 8]]
# action= right , depth= 31713 , step cost= 3 , total_cost= 143668
#
# step 31714
# [[5 4 2]
#  [7 1 3]
#  [6 0 8]]
# action= up , depth= 31714 , step cost= 1 , total_cost= 143669
#
# step 31715
# [[5 4 2]
#  [7 1 3]
#  [6 8 0]]
# action= left , depth= 31715 , step cost= 8 , total_cost= 143677
#
# step 31716
# [[5 4 2]
#  [7 1 0]
#  [6 8 3]]
# action= down , depth= 31716 , step cost= 3 , total_cost= 143680
#
# step 31717
# [[5 4 2]
#  [7 0 1]
#  [6 8 3]]
# action= right , depth= 31717 , step cost= 1 , total_cost= 143681
#
# step 31718
# [[5 4 2]
#  [7 8 1]
#  [6 0 3]]
# action= up , depth= 31718 , step cost= 8 , total_cost= 143689
#
# step 31719
# [[5 4 2]
#  [7 8 1]
#  [6 3 0]]
# action= left , depth= 31719 , step cost= 3 , total_cost= 143692
#
# step 31720
# [[5 4 2]
#  [7 8 0]
#  [6 3 1]]
# action= down , depth= 31720 , step cost= 1 , total_cost= 143693
#
# step 31721
# [[5 4 2]
#  [7 0 8]
#  [6 3 1]]
# action= right , depth= 31721 , step cost= 8 , total_cost= 143701
#
# step 31722
# [[5 4 2]
#  [0 7 8]
#  [6 3 1]]
# action= right , depth= 31722 , step cost= 7 , total_cost= 143708
#
# step 31723
# [[5 4 2]
#  [6 7 8]
#  [0 3 1]]
# action= up , depth= 31723 , step cost= 6 , total_cost= 143714
#
# step 31724
# [[5 4 2]
#  [6 7 8]
#  [3 0 1]]
# action= left , depth= 31724 , step cost= 3 , total_cost= 143717
#
# step 31725
# [[5 4 2]
#  [6 7 8]
#  [3 1 0]]
# action= left , depth= 31725 , step cost= 1 , total_cost= 143718
#
# step 31726
# [[5 4 2]
#  [6 7 0]
#  [3 1 8]]
# action= down , depth= 31726 , step cost= 8 , total_cost= 143726
#
# step 31727
# [[5 4 2]
#  [6 0 7]
#  [3 1 8]]
# action= right , depth= 31727 , step cost= 7 , total_cost= 143733
#
# step 31728
# [[5 4 2]
#  [6 1 7]
#  [3 0 8]]
# action= up , depth= 31728 , step cost= 1 , total_cost= 143734
#
# step 31729
# [[5 4 2]
#  [6 1 7]
#  [3 8 0]]
# action= left , depth= 31729 , step cost= 8 , total_cost= 143742
#
# step 31730
# [[5 4 2]
#  [6 1 0]
#  [3 8 7]]
# action= down , depth= 31730 , step cost= 7 , total_cost= 143749
#
# step 31731
# [[5 4 2]
#  [6 0 1]
#  [3 8 7]]
# action= right , depth= 31731 , step cost= 1 , total_cost= 143750
#
# step 31732
# [[5 4 2]
#  [0 6 1]
#  [3 8 7]]
# action= right , depth= 31732 , step cost= 6 , total_cost= 143756
#
# step 31733
# [[5 4 2]
#  [3 6 1]
#  [0 8 7]]
# action= up , depth= 31733 , step cost= 3 , total_cost= 143759
#
# step 31734
# [[5 4 2]
#  [3 6 1]
#  [8 0 7]]
# action= left , depth= 31734 , step cost= 8 , total_cost= 143767
#
# step 31735
# [[5 4 2]
#  [3 6 1]
#  [8 7 0]]
# action= left , depth= 31735 , step cost= 7 , total_cost= 143774
#
# step 31736
# [[5 4 2]
#  [3 6 0]
#  [8 7 1]]
# action= down , depth= 31736 , step cost= 1 , total_cost= 143775
#
# step 31737
# [[5 4 2]
#  [3 0 6]
#  [8 7 1]]
# action= right , depth= 31737 , step cost= 6 , total_cost= 143781
#
# step 31738
# [[5 4 2]
#  [3 7 6]
#  [8 0 1]]
# action= up , depth= 31738 , step cost= 7 , total_cost= 143788
#
# step 31739
# [[5 4 2]
#  [3 7 6]
#  [8 1 0]]
# action= left , depth= 31739 , step cost= 1 , total_cost= 143789
#
# step 31740
# [[5 4 2]
#  [3 7 0]
#  [8 1 6]]
# action= down , depth= 31740 , step cost= 6 , total_cost= 143795
#
# step 31741
# [[5 4 2]
#  [3 0 7]
#  [8 1 6]]
# action= right , depth= 31741 , step cost= 7 , total_cost= 143802
#
# step 31742
# [[5 4 2]
#  [3 1 7]
#  [8 0 6]]
# action= up , depth= 31742 , step cost= 1 , total_cost= 143803
#
# step 31743
# [[5 4 2]
#  [3 1 7]
#  [8 6 0]]
# action= left , depth= 31743 , step cost= 6 , total_cost= 143809
#
# step 31744
# [[5 4 2]
#  [3 1 0]
#  [8 6 7]]
# action= down , depth= 31744 , step cost= 7 , total_cost= 143816
#
# step 31745
# [[5 4 2]
#  [3 0 1]
#  [8 6 7]]
# action= right , depth= 31745 , step cost= 1 , total_cost= 143817
#
# step 31746
# [[5 4 2]
#  [0 3 1]
#  [8 6 7]]
# action= right , depth= 31746 , step cost= 3 , total_cost= 143820
#
# step 31747
# [[5 4 2]
#  [8 3 1]
#  [0 6 7]]
# action= up , depth= 31747 , step cost= 8 , total_cost= 143828
#
# step 31748
# [[5 4 2]
#  [8 3 1]
#  [6 0 7]]
# action= left , depth= 31748 , step cost= 6 , total_cost= 143834
#
# step 31749
# [[5 4 2]
#  [8 3 1]
#  [6 7 0]]
# action= left , depth= 31749 , step cost= 7 , total_cost= 143841
#
# step 31750
# [[5 4 2]
#  [8 3 0]
#  [6 7 1]]
# action= down , depth= 31750 , step cost= 1 , total_cost= 143842
#
# step 31751
# [[5 4 2]
#  [8 0 3]
#  [6 7 1]]
# action= right , depth= 31751 , step cost= 3 , total_cost= 143845
#
# step 31752
# [[5 4 2]
#  [8 7 3]
#  [6 0 1]]
# action= up , depth= 31752 , step cost= 7 , total_cost= 143852
#
# step 31753
# [[5 4 2]
#  [8 7 3]
#  [6 1 0]]
# action= left , depth= 31753 , step cost= 1 , total_cost= 143853
#
# step 31754
# [[5 4 2]
#  [8 7 0]
#  [6 1 3]]
# action= down , depth= 31754 , step cost= 3 , total_cost= 143856
#
# step 31755
# [[5 4 2]
#  [8 0 7]
#  [6 1 3]]
# action= right , depth= 31755 , step cost= 7 , total_cost= 143863
#
# step 31756
# [[5 4 2]
#  [0 8 7]
#  [6 1 3]]
# action= right , depth= 31756 , step cost= 8 , total_cost= 143871
#
# step 31757
# [[5 4 2]
#  [6 8 7]
#  [0 1 3]]
# action= up , depth= 31757 , step cost= 6 , total_cost= 143877
#
# step 31758
# [[5 4 2]
#  [6 8 7]
#  [1 0 3]]
# action= left , depth= 31758 , step cost= 1 , total_cost= 143878
#
# step 31759
# [[5 4 2]
#  [6 8 7]
#  [1 3 0]]
# action= left , depth= 31759 , step cost= 3 , total_cost= 143881
#
# step 31760
# [[5 4 2]
#  [6 8 0]
#  [1 3 7]]
# action= down , depth= 31760 , step cost= 7 , total_cost= 143888
#
# step 31761
# [[5 4 2]
#  [6 0 8]
#  [1 3 7]]
# action= right , depth= 31761 , step cost= 8 , total_cost= 143896
#
# step 31762
# [[5 4 2]
#  [6 3 8]
#  [1 0 7]]
# action= up , depth= 31762 , step cost= 3 , total_cost= 143899
#
# step 31763
# [[5 4 2]
#  [6 3 8]
#  [1 7 0]]
# action= left , depth= 31763 , step cost= 7 , total_cost= 143906
#
# step 31764
# [[5 4 2]
#  [6 3 0]
#  [1 7 8]]
# action= down , depth= 31764 , step cost= 8 , total_cost= 143914
#
# step 31765
# [[5 4 2]
#  [6 0 3]
#  [1 7 8]]
# action= right , depth= 31765 , step cost= 3 , total_cost= 143917
#
# step 31766
# [[5 4 2]
#  [6 7 3]
#  [1 0 8]]
# action= up , depth= 31766 , step cost= 7 , total_cost= 143924
#
# step 31767
# [[5 4 2]
#  [6 7 3]
#  [1 8 0]]
# action= left , depth= 31767 , step cost= 8 , total_cost= 143932
#
# step 31768
# [[5 4 2]
#  [6 7 0]
#  [1 8 3]]
# action= down , depth= 31768 , step cost= 3 , total_cost= 143935
#
# step 31769
# [[5 4 2]
#  [6 0 7]
#  [1 8 3]]
# action= right , depth= 31769 , step cost= 7 , total_cost= 143942
#
# step 31770
# [[5 4 2]
#  [0 6 7]
#  [1 8 3]]
# action= right , depth= 31770 , step cost= 6 , total_cost= 143948
#
# step 31771
# [[5 4 2]
#  [1 6 7]
#  [0 8 3]]
# action= up , depth= 31771 , step cost= 1 , total_cost= 143949
#
# step 31772
# [[5 4 2]
#  [1 6 7]
#  [8 0 3]]
# action= left , depth= 31772 , step cost= 8 , total_cost= 143957
#
# step 31773
# [[5 4 2]
#  [1 6 7]
#  [8 3 0]]
# action= left , depth= 31773 , step cost= 3 , total_cost= 143960
#
# step 31774
# [[5 4 2]
#  [1 6 0]
#  [8 3 7]]
# action= down , depth= 31774 , step cost= 7 , total_cost= 143967
#
# step 31775
# [[5 4 2]
#  [1 0 6]
#  [8 3 7]]
# action= right , depth= 31775 , step cost= 6 , total_cost= 143973
#
# step 31776
# [[5 4 2]
#  [1 3 6]
#  [8 0 7]]
# action= up , depth= 31776 , step cost= 3 , total_cost= 143976
#
# step 31777
# [[5 4 2]
#  [1 3 6]
#  [8 7 0]]
# action= left , depth= 31777 , step cost= 7 , total_cost= 143983
#
# step 31778
# [[5 4 2]
#  [1 3 0]
#  [8 7 6]]
# action= down , depth= 31778 , step cost= 6 , total_cost= 143989
#
# step 31779
# [[5 4 2]
#  [1 0 3]
#  [8 7 6]]
# action= right , depth= 31779 , step cost= 3 , total_cost= 143992
#
# step 31780
# [[5 4 2]
#  [0 1 3]
#  [8 7 6]]
# action= right , depth= 31780 , step cost= 1 , total_cost= 143993
#
# step 31781
# [[5 4 2]
#  [8 1 3]
#  [0 7 6]]
# action= up , depth= 31781 , step cost= 8 , total_cost= 144001
#
# step 31782
# [[5 4 2]
#  [8 1 3]
#  [7 0 6]]
# action= left , depth= 31782 , step cost= 7 , total_cost= 144008
#
# step 31783
# [[5 4 2]
#  [8 1 3]
#  [7 6 0]]
# action= left , depth= 31783 , step cost= 6 , total_cost= 144014
#
# step 31784
# [[5 4 2]
#  [8 1 0]
#  [7 6 3]]
# action= down , depth= 31784 , step cost= 3 , total_cost= 144017
#
# step 31785
# [[5 4 2]
#  [8 0 1]
#  [7 6 3]]
# action= right , depth= 31785 , step cost= 1 , total_cost= 144018
#
# step 31786
# [[5 4 2]
#  [8 6 1]
#  [7 0 3]]
# action= up , depth= 31786 , step cost= 6 , total_cost= 144024
#
# step 31787
# [[5 4 2]
#  [8 6 1]
#  [7 3 0]]
# action= left , depth= 31787 , step cost= 3 , total_cost= 144027
#
# step 31788
# [[5 4 2]
#  [8 6 0]
#  [7 3 1]]
# action= down , depth= 31788 , step cost= 1 , total_cost= 144028
#
# step 31789
# [[5 4 2]
#  [8 0 6]
#  [7 3 1]]
# action= right , depth= 31789 , step cost= 6 , total_cost= 144034
#
# step 31790
# [[5 4 2]
#  [8 3 6]
#  [7 0 1]]
# action= up , depth= 31790 , step cost= 3 , total_cost= 144037
#
# step 31791
# [[5 4 2]
#  [8 3 6]
#  [7 1 0]]
# action= left , depth= 31791 , step cost= 1 , total_cost= 144038
#
# step 31792
# [[5 4 2]
#  [8 3 0]
#  [7 1 6]]
# action= down , depth= 31792 , step cost= 6 , total_cost= 144044
#
# step 31793
# [[5 4 2]
#  [8 0 3]
#  [7 1 6]]
# action= right , depth= 31793 , step cost= 3 , total_cost= 144047
#
# step 31794
# [[5 4 2]
#  [0 8 3]
#  [7 1 6]]
# action= right , depth= 31794 , step cost= 8 , total_cost= 144055
#
# step 31795
# [[0 4 2]
#  [5 8 3]
#  [7 1 6]]
# action= down , depth= 31795 , step cost= 5 , total_cost= 144060
#
# step 31796
# [[4 0 2]
#  [5 8 3]
#  [7 1 6]]
# action= left , depth= 31796 , step cost= 4 , total_cost= 144064
#
# step 31797
# [[4 2 0]
#  [5 8 3]
#  [7 1 6]]
# action= left , depth= 31797 , step cost= 2 , total_cost= 144066
#
# step 31798
# [[4 2 3]
#  [5 8 0]
#  [7 1 6]]
# action= up , depth= 31798 , step cost= 3 , total_cost= 144069
#
# step 31799
# [[4 2 3]
#  [5 8 6]
#  [7 1 0]]
# action= up , depth= 31799 , step cost= 6 , total_cost= 144075
#
# step 31800
# [[4 2 3]
#  [5 8 6]
#  [7 0 1]]
# action= right , depth= 31800 , step cost= 1 , total_cost= 144076
#
# step 31801
# [[4 2 3]
#  [5 8 6]
#  [0 7 1]]
# action= right , depth= 31801 , step cost= 7 , total_cost= 144083
#
# step 31802
# [[4 2 3]
#  [0 8 6]
#  [5 7 1]]
# action= down , depth= 31802 , step cost= 5 , total_cost= 144088
#
# step 31803
# [[4 2 3]
#  [8 0 6]
#  [5 7 1]]
# action= left , depth= 31803 , step cost= 8 , total_cost= 144096
#
# step 31804
# [[4 2 3]
#  [8 6 0]
#  [5 7 1]]
# action= left , depth= 31804 , step cost= 6 , total_cost= 144102
#
# step 31805
# [[4 2 3]
#  [8 6 1]
#  [5 7 0]]
# action= up , depth= 31805 , step cost= 1 , total_cost= 144103
#
# step 31806
# [[4 2 3]
#  [8 6 1]
#  [5 0 7]]
# action= right , depth= 31806 , step cost= 7 , total_cost= 144110
#
# step 31807
# [[4 2 3]
#  [8 6 1]
#  [0 5 7]]
# action= right , depth= 31807 , step cost= 5 , total_cost= 144115
#
# step 31808
# [[4 2 3]
#  [0 6 1]
#  [8 5 7]]
# action= down , depth= 31808 , step cost= 8 , total_cost= 144123
#
# step 31809
# [[4 2 3]
#  [6 0 1]
#  [8 5 7]]
# action= left , depth= 31809 , step cost= 6 , total_cost= 144129
#
# step 31810
# [[4 2 3]
#  [6 1 0]
#  [8 5 7]]
# action= left , depth= 31810 , step cost= 1 , total_cost= 144130
#
# step 31811
# [[4 2 3]
#  [6 1 7]
#  [8 5 0]]
# action= up , depth= 31811 , step cost= 7 , total_cost= 144137
#
# step 31812
# [[4 2 3]
#  [6 1 7]
#  [8 0 5]]
# action= right , depth= 31812 , step cost= 5 , total_cost= 144142
#
# step 31813
# [[4 2 3]
#  [6 1 7]
#  [0 8 5]]
# action= right , depth= 31813 , step cost= 8 , total_cost= 144150
#
# step 31814
# [[4 2 3]
#  [0 1 7]
#  [6 8 5]]
# action= down , depth= 31814 , step cost= 6 , total_cost= 144156
#
# step 31815
# [[4 2 3]
#  [1 0 7]
#  [6 8 5]]
# action= left , depth= 31815 , step cost= 1 , total_cost= 144157
#
# step 31816
# [[4 2 3]
#  [1 7 0]
#  [6 8 5]]
# action= left , depth= 31816 , step cost= 7 , total_cost= 144164
#
# step 31817
# [[4 2 3]
#  [1 7 5]
#  [6 8 0]]
# action= up , depth= 31817 , step cost= 5 , total_cost= 144169
#
# step 31818
# [[4 2 3]
#  [1 7 5]
#  [6 0 8]]
# action= right , depth= 31818 , step cost= 8 , total_cost= 144177
#
# step 31819
# [[4 2 3]
#  [1 7 5]
#  [0 6 8]]
# action= right , depth= 31819 , step cost= 6 , total_cost= 144183
#
# step 31820
# [[4 2 3]
#  [0 7 5]
#  [1 6 8]]
# action= down , depth= 31820 , step cost= 1 , total_cost= 144184
#
# step 31821
# [[4 2 3]
#  [7 0 5]
#  [1 6 8]]
# action= left , depth= 31821 , step cost= 7 , total_cost= 144191
#
# step 31822
# [[4 2 3]
#  [7 5 0]
#  [1 6 8]]
# action= left , depth= 31822 , step cost= 5 , total_cost= 144196
#
# step 31823
# [[4 2 3]
#  [7 5 8]
#  [1 6 0]]
# action= up , depth= 31823 , step cost= 8 , total_cost= 144204
#
# step 31824
# [[4 2 3]
#  [7 5 8]
#  [1 0 6]]
# action= right , depth= 31824 , step cost= 6 , total_cost= 144210
#
# step 31825
# [[4 2 3]
#  [7 5 8]
#  [0 1 6]]
# action= right , depth= 31825 , step cost= 1 , total_cost= 144211
#
# step 31826
# [[4 2 3]
#  [0 5 8]
#  [7 1 6]]
# action= down , depth= 31826 , step cost= 7 , total_cost= 144218
#
# step 31827
# [[4 2 3]
#  [5 0 8]
#  [7 1 6]]
# action= left , depth= 31827 , step cost= 5 , total_cost= 144223
#
# step 31828
# [[4 2 3]
#  [5 1 8]
#  [7 0 6]]
# action= up , depth= 31828 , step cost= 1 , total_cost= 144224
#
# step 31829
# [[4 2 3]
#  [5 1 8]
#  [7 6 0]]
# action= left , depth= 31829 , step cost= 6 , total_cost= 144230
#
# step 31830
# [[4 2 3]
#  [5 1 0]
#  [7 6 8]]
# action= down , depth= 31830 , step cost= 8 , total_cost= 144238
#
# step 31831
# [[4 2 3]
#  [5 0 1]
#  [7 6 8]]
# action= right , depth= 31831 , step cost= 1 , total_cost= 144239
#
# step 31832
# [[4 2 3]
#  [5 6 1]
#  [7 0 8]]
# action= up , depth= 31832 , step cost= 6 , total_cost= 144245
#
# step 31833
# [[4 2 3]
#  [5 6 1]
#  [7 8 0]]
# action= left , depth= 31833 , step cost= 8 , total_cost= 144253
#
# step 31834
# [[4 2 3]
#  [5 6 0]
#  [7 8 1]]
# action= down , depth= 31834 , step cost= 1 , total_cost= 144254
#
# step 31835
# [[4 2 3]
#  [5 0 6]
#  [7 8 1]]
# action= right , depth= 31835 , step cost= 6 , total_cost= 144260
#
# step 31836
# [[4 2 3]
#  [0 5 6]
#  [7 8 1]]
# action= right , depth= 31836 , step cost= 5 , total_cost= 144265
#
# step 31837
# [[4 2 3]
#  [7 5 6]
#  [0 8 1]]
# action= up , depth= 31837 , step cost= 7 , total_cost= 144272
#
# step 31838
# [[4 2 3]
#  [7 5 6]
#  [8 0 1]]
# action= left , depth= 31838 , step cost= 8 , total_cost= 144280
#
# step 31839
# [[4 2 3]
#  [7 5 6]
#  [8 1 0]]
# action= left , depth= 31839 , step cost= 1 , total_cost= 144281
#
# step 31840
# [[4 2 3]
#  [7 5 0]
#  [8 1 6]]
# action= down , depth= 31840 , step cost= 6 , total_cost= 144287
#
# step 31841
# [[4 2 3]
#  [7 0 5]
#  [8 1 6]]
# action= right , depth= 31841 , step cost= 5 , total_cost= 144292
#
# step 31842
# [[4 2 3]
#  [7 1 5]
#  [8 0 6]]
# action= up , depth= 31842 , step cost= 1 , total_cost= 144293
#
# step 31843
# [[4 2 3]
#  [7 1 5]
#  [8 6 0]]
# action= left , depth= 31843 , step cost= 6 , total_cost= 144299
#
# step 31844
# [[4 2 3]
#  [7 1 0]
#  [8 6 5]]
# action= down , depth= 31844 , step cost= 5 , total_cost= 144304
#
# step 31845
# [[4 2 3]
#  [7 0 1]
#  [8 6 5]]
# action= right , depth= 31845 , step cost= 1 , total_cost= 144305
#
# step 31846
# [[4 2 3]
#  [7 6 1]
#  [8 0 5]]
# action= up , depth= 31846 , step cost= 6 , total_cost= 144311
#
# step 31847
# [[4 2 3]
#  [7 6 1]
#  [8 5 0]]
# action= left , depth= 31847 , step cost= 5 , total_cost= 144316
#
# step 31848
# [[4 2 3]
#  [7 6 0]
#  [8 5 1]]
# action= down , depth= 31848 , step cost= 1 , total_cost= 144317
#
# step 31849
# [[4 2 3]
#  [7 0 6]
#  [8 5 1]]
# action= right , depth= 31849 , step cost= 6 , total_cost= 144323
#
# step 31850
# [[4 2 3]
#  [0 7 6]
#  [8 5 1]]
# action= right , depth= 31850 , step cost= 7 , total_cost= 144330
#
# step 31851
# [[4 2 3]
#  [8 7 6]
#  [0 5 1]]
# action= up , depth= 31851 , step cost= 8 , total_cost= 144338
#
# step 31852
# [[4 2 3]
#  [8 7 6]
#  [5 0 1]]
# action= left , depth= 31852 , step cost= 5 , total_cost= 144343
#
# step 31853
# [[4 2 3]
#  [8 7 6]
#  [5 1 0]]
# action= left , depth= 31853 , step cost= 1 , total_cost= 144344
#
# step 31854
# [[4 2 3]
#  [8 7 0]
#  [5 1 6]]
# action= down , depth= 31854 , step cost= 6 , total_cost= 144350
#
# step 31855
# [[4 2 3]
#  [8 0 7]
#  [5 1 6]]
# action= right , depth= 31855 , step cost= 7 , total_cost= 144357
#
# step 31856
# [[4 2 3]
#  [8 1 7]
#  [5 0 6]]
# action= up , depth= 31856 , step cost= 1 , total_cost= 144358
#
# step 31857
# [[4 2 3]
#  [8 1 7]
#  [5 6 0]]
# action= left , depth= 31857 , step cost= 6 , total_cost= 144364
#
# step 31858
# [[4 2 3]
#  [8 1 0]
#  [5 6 7]]
# action= down , depth= 31858 , step cost= 7 , total_cost= 144371
#
# step 31859
# [[4 2 3]
#  [8 0 1]
#  [5 6 7]]
# action= right , depth= 31859 , step cost= 1 , total_cost= 144372
#
# step 31860
# [[4 2 3]
#  [0 8 1]
#  [5 6 7]]
# action= right , depth= 31860 , step cost= 8 , total_cost= 144380
#
# step 31861
# [[4 2 3]
#  [5 8 1]
#  [0 6 7]]
# action= up , depth= 31861 , step cost= 5 , total_cost= 144385
#
# step 31862
# [[4 2 3]
#  [5 8 1]
#  [6 0 7]]
# action= left , depth= 31862 , step cost= 6 , total_cost= 144391
#
# step 31863
# [[4 2 3]
#  [5 8 1]
#  [6 7 0]]
# action= left , depth= 31863 , step cost= 7 , total_cost= 144398
#
# step 31864
# [[4 2 3]
#  [5 8 0]
#  [6 7 1]]
# action= down , depth= 31864 , step cost= 1 , total_cost= 144399
#
# step 31865
# [[4 2 3]
#  [5 0 8]
#  [6 7 1]]
# action= right , depth= 31865 , step cost= 8 , total_cost= 144407
#
# step 31866
# [[4 2 3]
#  [5 7 8]
#  [6 0 1]]
# action= up , depth= 31866 , step cost= 7 , total_cost= 144414
#
# step 31867
# [[4 2 3]
#  [5 7 8]
#  [6 1 0]]
# action= left , depth= 31867 , step cost= 1 , total_cost= 144415
#
# step 31868
# [[4 2 3]
#  [5 7 0]
#  [6 1 8]]
# action= down , depth= 31868 , step cost= 8 , total_cost= 144423
#
# step 31869
# [[4 2 3]
#  [5 0 7]
#  [6 1 8]]
# action= right , depth= 31869 , step cost= 7 , total_cost= 144430
#
# step 31870
# [[4 2 3]
#  [5 1 7]
#  [6 0 8]]
# action= up , depth= 31870 , step cost= 1 , total_cost= 144431
#
# step 31871
# [[4 2 3]
#  [5 1 7]
#  [6 8 0]]
# action= left , depth= 31871 , step cost= 8 , total_cost= 144439
#
# step 31872
# [[4 2 3]
#  [5 1 0]
#  [6 8 7]]
# action= down , depth= 31872 , step cost= 7 , total_cost= 144446
#
# step 31873
# [[4 2 3]
#  [5 0 1]
#  [6 8 7]]
# action= right , depth= 31873 , step cost= 1 , total_cost= 144447
#
# step 31874
# [[4 2 3]
#  [0 5 1]
#  [6 8 7]]
# action= right , depth= 31874 , step cost= 5 , total_cost= 144452
#
# step 31875
# [[4 2 3]
#  [6 5 1]
#  [0 8 7]]
# action= up , depth= 31875 , step cost= 6 , total_cost= 144458
#
# step 31876
# [[4 2 3]
#  [6 5 1]
#  [8 0 7]]
# action= left , depth= 31876 , step cost= 8 , total_cost= 144466
#
# step 31877
# [[4 2 3]
#  [6 5 1]
#  [8 7 0]]
# action= left , depth= 31877 , step cost= 7 , total_cost= 144473
#
# step 31878
# [[4 2 3]
#  [6 5 0]
#  [8 7 1]]
# action= down , depth= 31878 , step cost= 1 , total_cost= 144474
#
# step 31879
# [[4 2 3]
#  [6 0 5]
#  [8 7 1]]
# action= right , depth= 31879 , step cost= 5 , total_cost= 144479
#
# step 31880
# [[4 2 3]
#  [6 7 5]
#  [8 0 1]]
# action= up , depth= 31880 , step cost= 7 , total_cost= 144486
#
# step 31881
# [[4 2 3]
#  [6 7 5]
#  [8 1 0]]
# action= left , depth= 31881 , step cost= 1 , total_cost= 144487
#
# step 31882
# [[4 2 3]
#  [6 7 0]
#  [8 1 5]]
# action= down , depth= 31882 , step cost= 5 , total_cost= 144492
#
# step 31883
# [[4 2 3]
#  [6 0 7]
#  [8 1 5]]
# action= right , depth= 31883 , step cost= 7 , total_cost= 144499
#
# step 31884
# [[4 2 3]
#  [0 6 7]
#  [8 1 5]]
# action= right , depth= 31884 , step cost= 6 , total_cost= 144505
#
# step 31885
# [[4 2 3]
#  [8 6 7]
#  [0 1 5]]
# action= up , depth= 31885 , step cost= 8 , total_cost= 144513
#
# step 31886
# [[4 2 3]
#  [8 6 7]
#  [1 0 5]]
# action= left , depth= 31886 , step cost= 1 , total_cost= 144514
#
# step 31887
# [[4 2 3]
#  [8 6 7]
#  [1 5 0]]
# action= left , depth= 31887 , step cost= 5 , total_cost= 144519
#
# step 31888
# [[4 2 3]
#  [8 6 0]
#  [1 5 7]]
# action= down , depth= 31888 , step cost= 7 , total_cost= 144526
#
# step 31889
# [[4 2 3]
#  [8 0 6]
#  [1 5 7]]
# action= right , depth= 31889 , step cost= 6 , total_cost= 144532
#
# step 31890
# [[4 2 3]
#  [8 5 6]
#  [1 0 7]]
# action= up , depth= 31890 , step cost= 5 , total_cost= 144537
#
# step 31891
# [[4 2 3]
#  [8 5 6]
#  [1 7 0]]
# action= left , depth= 31891 , step cost= 7 , total_cost= 144544
#
# step 31892
# [[4 2 3]
#  [8 5 0]
#  [1 7 6]]
# action= down , depth= 31892 , step cost= 6 , total_cost= 144550
#
# step 31893
# [[4 2 3]
#  [8 0 5]
#  [1 7 6]]
# action= right , depth= 31893 , step cost= 5 , total_cost= 144555
#
# step 31894
# [[4 2 3]
#  [8 7 5]
#  [1 0 6]]
# action= up , depth= 31894 , step cost= 7 , total_cost= 144562
#
# step 31895
# [[4 2 3]
#  [8 7 5]
#  [1 6 0]]
# action= left , depth= 31895 , step cost= 6 , total_cost= 144568
#
# step 31896
# [[4 2 3]
#  [8 7 0]
#  [1 6 5]]
# action= down , depth= 31896 , step cost= 5 , total_cost= 144573
#
# step 31897
# [[4 2 3]
#  [8 0 7]
#  [1 6 5]]
# action= right , depth= 31897 , step cost= 7 , total_cost= 144580
#
# step 31898
# [[4 2 3]
#  [0 8 7]
#  [1 6 5]]
# action= right , depth= 31898 , step cost= 8 , total_cost= 144588
#
# step 31899
# [[4 2 3]
#  [1 8 7]
#  [0 6 5]]
# action= up , depth= 31899 , step cost= 1 , total_cost= 144589
#
# step 31900
# [[4 2 3]
#  [1 8 7]
#  [6 0 5]]
# action= left , depth= 31900 , step cost= 6 , total_cost= 144595
#
# step 31901
# [[4 2 3]
#  [1 8 7]
#  [6 5 0]]
# action= left , depth= 31901 , step cost= 5 , total_cost= 144600
#
# step 31902
# [[4 2 3]
#  [1 8 0]
#  [6 5 7]]
# action= down , depth= 31902 , step cost= 7 , total_cost= 144607
#
# step 31903
# [[4 2 3]
#  [1 0 8]
#  [6 5 7]]
# action= right , depth= 31903 , step cost= 8 , total_cost= 144615
#
# step 31904
# [[4 2 3]
#  [1 5 8]
#  [6 0 7]]
# action= up , depth= 31904 , step cost= 5 , total_cost= 144620
#
# step 31905
# [[4 2 3]
#  [1 5 8]
#  [6 7 0]]
# action= left , depth= 31905 , step cost= 7 , total_cost= 144627
#
# step 31906
# [[4 2 3]
#  [1 5 0]
#  [6 7 8]]
# action= down , depth= 31906 , step cost= 8 , total_cost= 144635
#
# step 31907
# [[4 2 3]
#  [1 0 5]
#  [6 7 8]]
# action= right , depth= 31907 , step cost= 5 , total_cost= 144640
#
# step 31908
# [[4 2 3]
#  [0 1 5]
#  [6 7 8]]
# action= right , depth= 31908 , step cost= 1 , total_cost= 144641
#
# step 31909
# [[4 2 3]
#  [6 1 5]
#  [0 7 8]]
# action= up , depth= 31909 , step cost= 6 , total_cost= 144647
#
# step 31910
# [[4 2 3]
#  [6 1 5]
#  [7 0 8]]
# action= left , depth= 31910 , step cost= 7 , total_cost= 144654
#
# step 31911
# [[4 2 3]
#  [6 1 5]
#  [7 8 0]]
# action= left , depth= 31911 , step cost= 8 , total_cost= 144662
#
# step 31912
# [[4 2 3]
#  [6 1 0]
#  [7 8 5]]
# action= down , depth= 31912 , step cost= 5 , total_cost= 144667
#
# step 31913
# [[4 2 3]
#  [6 0 1]
#  [7 8 5]]
# action= right , depth= 31913 , step cost= 1 , total_cost= 144668
#
# step 31914
# [[4 2 3]
#  [6 8 1]
#  [7 0 5]]
# action= up , depth= 31914 , step cost= 8 , total_cost= 144676
#
# step 31915
# [[4 2 3]
#  [6 8 1]
#  [7 5 0]]
# action= left , depth= 31915 , step cost= 5 , total_cost= 144681
#
# step 31916
# [[4 2 3]
#  [6 8 0]
#  [7 5 1]]
# action= down , depth= 31916 , step cost= 1 , total_cost= 144682
#
# step 31917
# [[4 2 3]
#  [6 0 8]
#  [7 5 1]]
# action= right , depth= 31917 , step cost= 8 , total_cost= 144690
#
# step 31918
# [[4 2 3]
#  [6 5 8]
#  [7 0 1]]
# action= up , depth= 31918 , step cost= 5 , total_cost= 144695
#
# step 31919
# [[4 2 3]
#  [6 5 8]
#  [7 1 0]]
# action= left , depth= 31919 , step cost= 1 , total_cost= 144696
#
# step 31920
# [[4 2 3]
#  [6 5 0]
#  [7 1 8]]
# action= down , depth= 31920 , step cost= 8 , total_cost= 144704
#
# step 31921
# [[4 2 3]
#  [6 0 5]
#  [7 1 8]]
# action= right , depth= 31921 , step cost= 5 , total_cost= 144709
#
# step 31922
# [[4 2 3]
#  [0 6 5]
#  [7 1 8]]
# action= right , depth= 31922 , step cost= 6 , total_cost= 144715
#
# step 31923
# [[4 2 3]
#  [7 6 5]
#  [0 1 8]]
# action= up , depth= 31923 , step cost= 7 , total_cost= 144722
#
# step 31924
# [[4 2 3]
#  [7 6 5]
#  [1 0 8]]
# action= left , depth= 31924 , step cost= 1 , total_cost= 144723
#
# step 31925
# [[4 2 3]
#  [7 6 5]
#  [1 8 0]]
# action= left , depth= 31925 , step cost= 8 , total_cost= 144731
#
# step 31926
# [[4 2 3]
#  [7 6 0]
#  [1 8 5]]
# action= down , depth= 31926 , step cost= 5 , total_cost= 144736
#
# step 31927
# [[4 2 3]
#  [7 0 6]
#  [1 8 5]]
# action= right , depth= 31927 , step cost= 6 , total_cost= 144742
#
# step 31928
# [[4 2 3]
#  [7 8 6]
#  [1 0 5]]
# action= up , depth= 31928 , step cost= 8 , total_cost= 144750
#
# step 31929
# [[4 2 3]
#  [7 8 6]
#  [1 5 0]]
# action= left , depth= 31929 , step cost= 5 , total_cost= 144755
#
# step 31930
# [[4 2 3]
#  [7 8 0]
#  [1 5 6]]
# action= down , depth= 31930 , step cost= 6 , total_cost= 144761
#
# step 31931
# [[4 2 3]
#  [7 0 8]
#  [1 5 6]]
# action= right , depth= 31931 , step cost= 8 , total_cost= 144769
#
# step 31932
# [[4 2 3]
#  [0 7 8]
#  [1 5 6]]
# action= right , depth= 31932 , step cost= 7 , total_cost= 144776
#
# step 31933
# [[4 2 3]
#  [1 7 8]
#  [0 5 6]]
# action= up , depth= 31933 , step cost= 1 , total_cost= 144777
#
# step 31934
# [[4 2 3]
#  [1 7 8]
#  [5 0 6]]
# action= left , depth= 31934 , step cost= 5 , total_cost= 144782
#
# step 31935
# [[4 2 3]
#  [1 7 8]
#  [5 6 0]]
# action= left , depth= 31935 , step cost= 6 , total_cost= 144788
#
# step 31936
# [[4 2 3]
#  [1 7 0]
#  [5 6 8]]
# action= down , depth= 31936 , step cost= 8 , total_cost= 144796
#
# step 31937
# [[4 2 3]
#  [1 0 7]
#  [5 6 8]]
# action= right , depth= 31937 , step cost= 7 , total_cost= 144803
#
# step 31938
# [[4 2 3]
#  [1 6 7]
#  [5 0 8]]
# action= up , depth= 31938 , step cost= 6 , total_cost= 144809
#
# step 31939
# [[4 2 3]
#  [1 6 7]
#  [5 8 0]]
# action= left , depth= 31939 , step cost= 8 , total_cost= 144817
#
# step 31940
# [[4 2 3]
#  [1 6 0]
#  [5 8 7]]
# action= down , depth= 31940 , step cost= 7 , total_cost= 144824
#
# step 31941
# [[4 2 3]
#  [1 0 6]
#  [5 8 7]]
# action= right , depth= 31941 , step cost= 6 , total_cost= 144830
#
# step 31942
# [[4 2 3]
#  [1 8 6]
#  [5 0 7]]
# action= up , depth= 31942 , step cost= 8 , total_cost= 144838
#
# step 31943
# [[4 2 3]
#  [1 8 6]
#  [5 7 0]]
# action= left , depth= 31943 , step cost= 7 , total_cost= 144845
#
# step 31944
# [[4 2 3]
#  [1 8 0]
#  [5 7 6]]
# action= down , depth= 31944 , step cost= 6 , total_cost= 144851
#
# step 31945
# [[4 2 3]
#  [1 0 8]
#  [5 7 6]]
# action= right , depth= 31945 , step cost= 8 , total_cost= 144859
#
# step 31946
# [[4 2 3]
#  [0 1 8]
#  [5 7 6]]
# action= right , depth= 31946 , step cost= 1 , total_cost= 144860
#
# step 31947
# [[0 2 3]
#  [4 1 8]
#  [5 7 6]]
# action= down , depth= 31947 , step cost= 4 , total_cost= 144864
#
# step 31948
# [[2 0 3]
#  [4 1 8]
#  [5 7 6]]
# action= left , depth= 31948 , step cost= 2 , total_cost= 144866
#
# step 31949
# [[2 3 0]
#  [4 1 8]
#  [5 7 6]]
# action= left , depth= 31949 , step cost= 3 , total_cost= 144869
#
# step 31950
# [[2 3 8]
#  [4 1 0]
#  [5 7 6]]
# action= up , depth= 31950 , step cost= 8 , total_cost= 144877
#
# step 31951
# [[2 3 8]
#  [4 1 6]
#  [5 7 0]]
# action= up , depth= 31951 , step cost= 6 , total_cost= 144883
#
# step 31952
# [[2 3 8]
#  [4 1 6]
#  [5 0 7]]
# action= right , depth= 31952 , step cost= 7 , total_cost= 144890
#
# step 31953
# [[2 3 8]
#  [4 1 6]
#  [0 5 7]]
# action= right , depth= 31953 , step cost= 5 , total_cost= 144895
#
# step 31954
# [[2 3 8]
#  [0 1 6]
#  [4 5 7]]
# action= down , depth= 31954 , step cost= 4 , total_cost= 144899
#
# step 31955
# [[2 3 8]
#  [1 0 6]
#  [4 5 7]]
# action= left , depth= 31955 , step cost= 1 , total_cost= 144900
#
# step 31956
# [[2 3 8]
#  [1 6 0]
#  [4 5 7]]
# action= left , depth= 31956 , step cost= 6 , total_cost= 144906
#
# step 31957
# [[2 3 8]
#  [1 6 7]
#  [4 5 0]]
# action= up , depth= 31957 , step cost= 7 , total_cost= 144913
#
# step 31958
# [[2 3 8]
#  [1 6 7]
#  [4 0 5]]
# action= right , depth= 31958 , step cost= 5 , total_cost= 144918
#
# step 31959
# [[2 3 8]
#  [1 6 7]
#  [0 4 5]]
# action= right , depth= 31959 , step cost= 4 , total_cost= 144922
#
# step 31960
# [[2 3 8]
#  [0 6 7]
#  [1 4 5]]
# action= down , depth= 31960 , step cost= 1 , total_cost= 144923
#
# step 31961
# [[2 3 8]
#  [6 0 7]
#  [1 4 5]]
# action= left , depth= 31961 , step cost= 6 , total_cost= 144929
#
# step 31962
# [[2 3 8]
#  [6 7 0]
#  [1 4 5]]
# action= left , depth= 31962 , step cost= 7 , total_cost= 144936
#
# step 31963
# [[2 3 8]
#  [6 7 5]
#  [1 4 0]]
# action= up , depth= 31963 , step cost= 5 , total_cost= 144941
#
# step 31964
# [[2 3 8]
#  [6 7 5]
#  [1 0 4]]
# action= right , depth= 31964 , step cost= 4 , total_cost= 144945
#
# step 31965
# [[2 3 8]
#  [6 7 5]
#  [0 1 4]]
# action= right , depth= 31965 , step cost= 1 , total_cost= 144946
#
# step 31966
# [[2 3 8]
#  [0 7 5]
#  [6 1 4]]
# action= down , depth= 31966 , step cost= 6 , total_cost= 144952
#
# step 31967
# [[2 3 8]
#  [7 0 5]
#  [6 1 4]]
# action= left , depth= 31967 , step cost= 7 , total_cost= 144959
#
# step 31968
# [[2 3 8]
#  [7 5 0]
#  [6 1 4]]
# action= left , depth= 31968 , step cost= 5 , total_cost= 144964
#
# step 31969
# [[2 3 8]
#  [7 5 4]
#  [6 1 0]]
# action= up , depth= 31969 , step cost= 4 , total_cost= 144968
#
# step 31970
# [[2 3 8]
#  [7 5 4]
#  [6 0 1]]
# action= right , depth= 31970 , step cost= 1 , total_cost= 144969
#
# step 31971
# [[2 3 8]
#  [7 5 4]
#  [0 6 1]]
# action= right , depth= 31971 , step cost= 6 , total_cost= 144975
#
# step 31972
# [[2 3 8]
#  [0 5 4]
#  [7 6 1]]
# action= down , depth= 31972 , step cost= 7 , total_cost= 144982
#
# step 31973
# [[2 3 8]
#  [5 0 4]
#  [7 6 1]]
# action= left , depth= 31973 , step cost= 5 , total_cost= 144987
#
# step 31974
# [[2 3 8]
#  [5 4 0]
#  [7 6 1]]
# action= left , depth= 31974 , step cost= 4 , total_cost= 144991
#
# step 31975
# [[2 3 8]
#  [5 4 1]
#  [7 6 0]]
# action= up , depth= 31975 , step cost= 1 , total_cost= 144992
#
# step 31976
# [[2 3 8]
#  [5 4 1]
#  [7 0 6]]
# action= right , depth= 31976 , step cost= 6 , total_cost= 144998
#
# step 31977
# [[2 3 8]
#  [5 4 1]
#  [0 7 6]]
# action= right , depth= 31977 , step cost= 7 , total_cost= 145005
#
# step 31978
# [[2 3 8]
#  [0 4 1]
#  [5 7 6]]
# action= down , depth= 31978 , step cost= 5 , total_cost= 145010
#
# step 31979
# [[2 3 8]
#  [4 0 1]
#  [5 7 6]]
# action= left , depth= 31979 , step cost= 4 , total_cost= 145014
#
# step 31980
# [[2 3 8]
#  [4 7 1]
#  [5 0 6]]
# action= up , depth= 31980 , step cost= 7 , total_cost= 145021
#
# step 31981
# [[2 3 8]
#  [4 7 1]
#  [5 6 0]]
# action= left , depth= 31981 , step cost= 6 , total_cost= 145027
#
# step 31982
# [[2 3 8]
#  [4 7 0]
#  [5 6 1]]
# action= down , depth= 31982 , step cost= 1 , total_cost= 145028
#
# step 31983
# [[2 3 8]
#  [4 0 7]
#  [5 6 1]]
# action= right , depth= 31983 , step cost= 7 , total_cost= 145035
#
# step 31984
# [[2 3 8]
#  [4 6 7]
#  [5 0 1]]
# action= up , depth= 31984 , step cost= 6 , total_cost= 145041
#
# step 31985
# [[2 3 8]
#  [4 6 7]
#  [5 1 0]]
# action= left , depth= 31985 , step cost= 1 , total_cost= 145042
#
# step 31986
# [[2 3 8]
#  [4 6 0]
#  [5 1 7]]
# action= down , depth= 31986 , step cost= 7 , total_cost= 145049
#
# step 31987
# [[2 3 8]
#  [4 0 6]
#  [5 1 7]]
# action= right , depth= 31987 , step cost= 6 , total_cost= 145055
#
# step 31988
# [[2 3 8]
#  [0 4 6]
#  [5 1 7]]
# action= right , depth= 31988 , step cost= 4 , total_cost= 145059
#
# step 31989
# [[2 3 8]
#  [5 4 6]
#  [0 1 7]]
# action= up , depth= 31989 , step cost= 5 , total_cost= 145064
#
# step 31990
# [[2 3 8]
#  [5 4 6]
#  [1 0 7]]
# action= left , depth= 31990 , step cost= 1 , total_cost= 145065
#
# step 31991
# [[2 3 8]
#  [5 4 6]
#  [1 7 0]]
# action= left , depth= 31991 , step cost= 7 , total_cost= 145072
#
# step 31992
# [[2 3 8]
#  [5 4 0]
#  [1 7 6]]
# action= down , depth= 31992 , step cost= 6 , total_cost= 145078
#
# step 31993
# [[2 3 8]
#  [5 0 4]
#  [1 7 6]]
# action= right , depth= 31993 , step cost= 4 , total_cost= 145082
#
# step 31994
# [[2 3 8]
#  [5 7 4]
#  [1 0 6]]
# action= up , depth= 31994 , step cost= 7 , total_cost= 145089
#
# step 31995
# [[2 3 8]
#  [5 7 4]
#  [1 6 0]]
# action= left , depth= 31995 , step cost= 6 , total_cost= 145095
#
# step 31996
# [[2 3 8]
#  [5 7 0]
#  [1 6 4]]
# action= down , depth= 31996 , step cost= 4 , total_cost= 145099
#
# step 31997
# [[2 3 8]
#  [5 0 7]
#  [1 6 4]]
# ...
#
# step 32223
# [[7 8 1]
#  [2 6 4]
#  [5 3 0]]
# action= left , depth= 32223 , step cost= 3 , total_cost= 146070
#
# step 32224
# [[7 8 1]
#  [2 6 0]
#  [5 3 4]]
# action= down , depth= 32224 , step cost= 4 , total_cost= 146074
#
# step 32225
# [[7 8 1]
#  [2 0 6]
#  [5 3 4]]
# action= right , depth= 32225 , step cost= 6 , total_cost= 146080
#
# step 32226
# [[7 8 1]
#  [2 3 6]
#  [5 0 4]]
# action= up , depth= 32226 , step cost= 3 , total_cost= 146083
#
# step 32227
# [[7 8 1]
#  [2 3 6]
#  [5 4 0]]
# action= left , depth= 32227 , step cost= 4 , total_cost= 146087
#
# step 32228
# [[7 8 1]
#  [2 3 0]
#  [5 4 6]]
# action= down , depth= 32228 , step cost= 6 , total_cost= 146093
#
# step 32229
# [[7 8 1]
#  [2 0 3]
#  [5 4 6]]
# action= right , depth= 32229 , step cost= 3 , total_cost= 146096
#
# step 32230
# [[7 8 1]
#  [2 4 3]
#  [5 0 6]]
# action= up , depth= 32230 , step cost= 4 , total_cost= 146100
#
# step 32231
# [[7 8 1]
#  [2 4 3]
#  [5 6 0]]
# action= left , depth= 32231 , step cost= 6 , total_cost= 146106
#
# step 32232
# [[7 8 1]
#  [2 4 0]
#  [5 6 3]]
# action= down , depth= 32232 , step cost= 3 , total_cost= 146109
#
# step 32233
# [[7 8 1]
#  [2 0 4]
#  [5 6 3]]
# action= right , depth= 32233 , step cost= 4 , total_cost= 146113
#
# step 32234
# [[7 8 1]
#  [0 2 4]
#  [5 6 3]]
# action= right , depth= 32234 , step cost= 2 , total_cost= 146115
#
# step 32235
# [[7 8 1]
#  [5 2 4]
#  [0 6 3]]
# action= up , depth= 32235 , step cost= 5 , total_cost= 146120
#
# step 32236
# [[7 8 1]
#  [5 2 4]
#  [6 0 3]]
# action= left , depth= 32236 , step cost= 6 , total_cost= 146126
#
# step 32237
# [[7 8 1]
#  [5 2 4]
#  [6 3 0]]
# action= left , depth= 32237 , step cost= 3 , total_cost= 146129
#
# step 32238
# [[7 8 1]
#  [5 2 0]
#  [6 3 4]]
# action= down , depth= 32238 , step cost= 4 , total_cost= 146133
#
# step 32239
# [[7 8 1]
#  [5 0 2]
#  [6 3 4]]
# action= right , depth= 32239 , step cost= 2 , total_cost= 146135
#
# step 32240
# [[7 8 1]
#  [5 3 2]
#  [6 0 4]]
# action= up , depth= 32240 , step cost= 3 , total_cost= 146138
#
# step 32241
# [[7 8 1]
#  [5 3 2]
#  [6 4 0]]
# action= left , depth= 32241 , step cost= 4 , total_cost= 146142
#
# step 32242
# [[7 8 1]
#  [5 3 0]
#  [6 4 2]]
# action= down , depth= 32242 , step cost= 2 , total_cost= 146144
#
# step 32243
# [[7 8 1]
#  [5 0 3]
#  [6 4 2]]
# action= right , depth= 32243 , step cost= 3 , total_cost= 146147
#
# step 32244
# [[7 8 1]
#  [0 5 3]
#  [6 4 2]]
# action= right , depth= 32244 , step cost= 5 , total_cost= 146152
#
# step 32245
# [[7 8 1]
#  [6 5 3]
#  [0 4 2]]
# action= up , depth= 32245 , step cost= 6 , total_cost= 146158
#
# step 32246
# [[7 8 1]
#  [6 5 3]
#  [4 0 2]]
# action= left , depth= 32246 , step cost= 4 , total_cost= 146162
#
# step 32247
# [[7 8 1]
#  [6 5 3]
#  [4 2 0]]
# action= left , depth= 32247 , step cost= 2 , total_cost= 146164
#
# step 32248
# [[7 8 1]
#  [6 5 0]
#  [4 2 3]]
# action= down , depth= 32248 , step cost= 3 , total_cost= 146167
#
# step 32249
# [[7 8 1]
#  [6 0 5]
#  [4 2 3]]
# action= right , depth= 32249 , step cost= 5 , total_cost= 146172
#
# step 32250
# [[7 8 1]
#  [6 2 5]
#  [4 0 3]]
# action= up , depth= 32250 , step cost= 2 , total_cost= 146174
#
# step 32251
# [[7 8 1]
#  [6 2 5]
#  [4 3 0]]
# action= left , depth= 32251 , step cost= 3 , total_cost= 146177
#
# step 32252
# [[7 8 1]
#  [6 2 0]
#  [4 3 5]]
# action= down , depth= 32252 , step cost= 5 , total_cost= 146182
#
# step 32253
# [[7 8 1]
#  [6 0 2]
#  [4 3 5]]
# action= right , depth= 32253 , step cost= 2 , total_cost= 146184
#
# step 32254
# [[7 8 1]
#  [6 3 2]
#  [4 0 5]]
# action= up , depth= 32254 , step cost= 3 , total_cost= 146187
#
# step 32255
# [[7 8 1]
#  [6 3 2]
#  [4 5 0]]
# action= left , depth= 32255 , step cost= 5 , total_cost= 146192
#
# step 32256
# [[7 8 1]
#  [6 3 0]
#  [4 5 2]]
# action= down , depth= 32256 , step cost= 2 , total_cost= 146194
#
# step 32257
# [[7 8 1]
#  [6 0 3]
#  [4 5 2]]
# action= right , depth= 32257 , step cost= 3 , total_cost= 146197
#
# step 32258
# [[7 8 1]
#  [0 6 3]
#  [4 5 2]]
# action= right , depth= 32258 , step cost= 6 , total_cost= 146203
#
# step 32259
# [[7 8 1]
#  [4 6 3]
#  [0 5 2]]
# action= up , depth= 32259 , step cost= 4 , total_cost= 146207
#
# step 32260
# [[7 8 1]
#  [4 6 3]
#  [5 0 2]]
# action= left , depth= 32260 , step cost= 5 , total_cost= 146212
#
# step 32261
# [[7 8 1]
#  [4 6 3]
#  [5 2 0]]
# action= left , depth= 32261 , step cost= 2 , total_cost= 146214
#
# step 32262
# [[7 8 1]
#  [4 6 0]
#  [5 2 3]]
# action= down , depth= 32262 , step cost= 3 , total_cost= 146217
#
# step 32263
# [[7 8 1]
#  [4 0 6]
#  [5 2 3]]
# action= right , depth= 32263 , step cost= 6 , total_cost= 146223
#
# step 32264
# [[7 8 1]
#  [4 2 6]
#  [5 0 3]]
# action= up , depth= 32264 , step cost= 2 , total_cost= 146225
#
# step 32265
# [[7 8 1]
#  [4 2 6]
#  [5 3 0]]
# action= left , depth= 32265 , step cost= 3 , total_cost= 146228
#
# step 32266
# [[7 8 1]
#  [4 2 0]
#  [5 3 6]]
# action= down , depth= 32266 , step cost= 6 , total_cost= 146234
#
# step 32267
# [[7 8 1]
#  [4 0 2]
#  [5 3 6]]
# action= right , depth= 32267 , step cost= 2 , total_cost= 146236
#
# step 32268
# [[7 8 1]
#  [0 4 2]
#  [5 3 6]]
# action= right , depth= 32268 , step cost= 4 , total_cost= 146240
#
# step 32269
# [[7 8 1]
#  [5 4 2]
#  [0 3 6]]
# action= up , depth= 32269 , step cost= 5 , total_cost= 146245
#
# step 32270
# [[7 8 1]
#  [5 4 2]
#  [3 0 6]]
# action= left , depth= 32270 , step cost= 3 , total_cost= 146248
#
# step 32271
# [[7 8 1]
#  [5 4 2]
#  [3 6 0]]
# action= left , depth= 32271 , step cost= 6 , total_cost= 146254
#
# step 32272
# [[7 8 1]
#  [5 4 0]
#  [3 6 2]]
# action= down , depth= 32272 , step cost= 2 , total_cost= 146256
#
# step 32273
# [[7 8 1]
#  [5 0 4]
#  [3 6 2]]
# action= right , depth= 32273 , step cost= 4 , total_cost= 146260
#
# step 32274
# [[7 8 1]
#  [5 6 4]
#  [3 0 2]]
# action= up , depth= 32274 , step cost= 6 , total_cost= 146266
#
# step 32275
# [[7 8 1]
#  [5 6 4]
#  [3 2 0]]
# action= left , depth= 32275 , step cost= 2 , total_cost= 146268
#
# step 32276
# [[7 8 1]
#  [5 6 0]
#  [3 2 4]]
# action= down , depth= 32276 , step cost= 4 , total_cost= 146272
#
# step 32277
# [[7 8 1]
#  [5 0 6]
#  [3 2 4]]
# action= right , depth= 32277 , step cost= 6 , total_cost= 146278
#
# step 32278
# [[7 8 1]
#  [5 2 6]
#  [3 0 4]]
# action= up , depth= 32278 , step cost= 2 , total_cost= 146280
#
# step 32279
# [[7 8 1]
#  [5 2 6]
#  [3 4 0]]
# action= left , depth= 32279 , step cost= 4 , total_cost= 146284
#
# step 32280
# [[7 8 1]
#  [5 2 0]
#  [3 4 6]]
# action= down , depth= 32280 , step cost= 6 , total_cost= 146290
#
# step 32281
# [[7 8 1]
#  [5 0 2]
#  [3 4 6]]
# action= right , depth= 32281 , step cost= 2 , total_cost= 146292
#
# step 32282
# [[7 8 1]
#  [0 5 2]
#  [3 4 6]]
# action= right , depth= 32282 , step cost= 5 , total_cost= 146297
#
# step 32283
# [[0 8 1]
#  [7 5 2]
#  [3 4 6]]
# action= down , depth= 32283 , step cost= 7 , total_cost= 146304
#
# step 32284
# [[8 0 1]
#  [7 5 2]
#  [3 4 6]]
# action= left , depth= 32284 , step cost= 8 , total_cost= 146312
#
# step 32285
# [[8 1 0]
#  [7 5 2]
#  [3 4 6]]
# action= left , depth= 32285 , step cost= 1 , total_cost= 146313
#
# step 32286
# [[8 1 2]
#  [7 5 0]
#  [3 4 6]]
# action= up , depth= 32286 , step cost= 2 , total_cost= 146315
#
# step 32287
# [[8 1 2]
#  [7 5 6]
#  [3 4 0]]
# action= up , depth= 32287 , step cost= 6 , total_cost= 146321
#
# step 32288
# [[8 1 2]
#  [7 5 6]
#  [3 0 4]]
# action= right , depth= 32288 , step cost= 4 , total_cost= 146325
#
# step 32289
# [[8 1 2]
#  [7 5 6]
#  [0 3 4]]
# action= right , depth= 32289 , step cost= 3 , total_cost= 146328
#
# step 32290
# [[8 1 2]
#  [0 5 6]
#  [7 3 4]]
# action= down , depth= 32290 , step cost= 7 , total_cost= 146335
#
# step 32291
# [[8 1 2]
#  [5 0 6]
#  [7 3 4]]
# action= left , depth= 32291 , step cost= 5 , total_cost= 146340
#
# step 32292
# [[8 1 2]
#  [5 6 0]
#  [7 3 4]]
# action= left , depth= 32292 , step cost= 6 , total_cost= 146346
#
# step 32293
# [[8 1 2]
#  [5 6 4]
#  [7 3 0]]
# action= up , depth= 32293 , step cost= 4 , total_cost= 146350
#
# step 32294
# [[8 1 2]
#  [5 6 4]
#  [7 0 3]]
# action= right , depth= 32294 , step cost= 3 , total_cost= 146353
#
# step 32295
# [[8 1 2]
#  [5 6 4]
#  [0 7 3]]
# action= right , depth= 32295 , step cost= 7 , total_cost= 146360
#
# step 32296
# [[8 1 2]
#  [0 6 4]
#  [5 7 3]]
# action= down , depth= 32296 , step cost= 5 , total_cost= 146365
#
# step 32297
# [[8 1 2]
#  [6 0 4]
#  [5 7 3]]
# action= left , depth= 32297 , step cost= 6 , total_cost= 146371
#
# step 32298
# [[8 1 2]
#  [6 4 0]
#  [5 7 3]]
# action= left , depth= 32298 , step cost= 4 , total_cost= 146375
#
# step 32299
# [[8 1 2]
#  [6 4 3]
#  [5 7 0]]
# action= up , depth= 32299 , step cost= 3 , total_cost= 146378
#
# step 32300
# [[8 1 2]
#  [6 4 3]
#  [5 0 7]]
# action= right , depth= 32300 , step cost= 7 , total_cost= 146385
#
# step 32301
# [[8 1 2]
#  [6 4 3]
#  [0 5 7]]
# action= right , depth= 32301 , step cost= 5 , total_cost= 146390
#
# step 32302
# [[8 1 2]
#  [0 4 3]
#  [6 5 7]]
# action= down , depth= 32302 , step cost= 6 , total_cost= 146396
#
# step 32303
# [[0 1 2]
#  [8 4 3]
#  [6 5 7]]
# action= down , depth= 32303 , step cost= 8 , total_cost= 146404
#
# step 32304
# [[1 0 2]
#  [8 4 3]
#  [6 5 7]]
# action= left , depth= 32304 , step cost= 1 , total_cost= 146405
#
# step 32305
# [[1 2 0]
#  [8 4 3]
#  [6 5 7]]
# action= left , depth= 32305 , step cost= 2 , total_cost= 146407
#
# step 32306
# [[1 2 3]
#  [8 4 0]
#  [6 5 7]]
# action= up , depth= 32306 , step cost= 3 , total_cost= 146410
#
# step 32307
# [[1 2 3]
#  [8 4 7]
#  [6 5 0]]
# action= up , depth= 32307 , step cost= 7 , total_cost= 146417
#
# step 32308
# [[1 2 3]
#  [8 4 7]
#  [6 0 5]]
# action= right , depth= 32308 , step cost= 5 , total_cost= 146422
#
# step 32309
# [[1 2 3]
#  [8 4 7]
#  [0 6 5]]
# action= right , depth= 32309 , step cost= 6 , total_cost= 146428
#
# step 32310
# [[1 2 3]
#  [0 4 7]
#  [8 6 5]]
# action= down , depth= 32310 , step cost= 8 , total_cost= 146436
#
# step 32311
# [[1 2 3]
#  [4 0 7]
#  [8 6 5]]
# action= left , depth= 32311 , step cost= 4 , total_cost= 146440
#
# step 32312
# [[1 2 3]
#  [4 7 0]
#  [8 6 5]]
# action= left , depth= 32312 , step cost= 7 , total_cost= 146447
#
# step 32313
# [[1 2 3]
#  [4 7 5]
#  [8 6 0]]
# action= up , depth= 32313 , step cost= 5 , total_cost= 146452
#
# step 32314
# [[1 2 3]
#  [4 7 5]
#  [8 0 6]]
# action= right , depth= 32314 , step cost= 6 , total_cost= 146458
#
# step 32315
# [[1 2 3]
#  [4 7 5]
#  [0 8 6]]
# action= right , depth= 32315 , step cost= 8 , total_cost= 146466
#
# step 32316
# [[1 2 3]
#  [0 7 5]
#  [4 8 6]]
# action= down , depth= 32316 , step cost= 4 , total_cost= 146470
#
# step 32317
# [[1 2 3]
#  [7 0 5]
#  [4 8 6]]
# action= left , depth= 32317 , step cost= 7 , total_cost= 146477
#
# step 32318
# [[1 2 3]
#  [7 5 0]
#  [4 8 6]]
# action= left , depth= 32318 , step cost= 5 , total_cost= 146482
#
# step 32319
# [[1 2 3]
#  [7 5 6]
#  [4 8 0]]
# action= up , depth= 32319 , step cost= 6 , total_cost= 146488
#
# step 32320
# [[1 2 3]
#  [7 5 6]
#  [4 0 8]]
# action= right , depth= 32320 , step cost= 8 , total_cost= 146496
#
# step 32321
# [[1 2 3]
#  [7 5 6]
#  [0 4 8]]
# action= right , depth= 32321 , step cost= 4 , total_cost= 146500
#
# step 32322
# [[1 2 3]
#  [0 5 6]
#  [7 4 8]]
# action= down , depth= 32322 , step cost= 7 , total_cost= 146507
#
# step 32323
# [[1 2 3]
#  [5 0 6]
#  [7 4 8]]
# action= left , depth= 32323 , step cost= 5 , total_cost= 146512
#
# step 32324
# [[1 2 3]
#  [5 6 0]
#  [7 4 8]]
# action= left , depth= 32324 , step cost= 6 , total_cost= 146518
#
# step 32325
# [[1 2 3]
#  [5 6 8]
#  [7 4 0]]
# action= up , depth= 32325 , step cost= 8 , total_cost= 146526
#
# step 32326
# [[1 2 3]
#  [5 6 8]
#  [7 0 4]]
# action= right , depth= 32326 , step cost= 4 , total_cost= 146530
#
# step 32327
# [[1 2 3]
#  [5 6 8]
#  [0 7 4]]
# action= right , depth= 32327 , step cost= 7 , total_cost= 146537
#
# step 32328
# [[1 2 3]
#  [0 6 8]
#  [5 7 4]]
# action= down , depth= 32328 , step cost= 5 , total_cost= 146542
#
# step 32329
# [[1 2 3]
#  [6 0 8]
#  [5 7 4]]
# action= left , depth= 32329 , step cost= 6 , total_cost= 146548
#
# step 32330
# [[1 2 3]
#  [6 8 0]
#  [5 7 4]]
# action= left , depth= 32330 , step cost= 8 , total_cost= 146556
#
# step 32331
# [[1 2 3]
#  [6 8 4]
#  [5 7 0]]
# action= up , depth= 32331 , step cost= 4 , total_cost= 146560
#
# step 32332
# [[1 2 3]
#  [6 8 4]
#  [5 0 7]]
# action= right , depth= 32332 , step cost= 7 , total_cost= 146567
#
# step 32333
# [[1 2 3]
#  [6 8 4]
#  [0 5 7]]
# action= right , depth= 32333 , step cost= 5 , total_cost= 146572
#
# step 32334
# [[1 2 3]
#  [0 8 4]
#  [6 5 7]]
# action= down , depth= 32334 , step cost= 6 , total_cost= 146578
#
# step 32335
# [[1 2 3]
#  [8 0 4]
#  [6 5 7]]
# action= left , depth= 32335 , step cost= 8 , total_cost= 146586
#
# step 32336
# [[1 2 3]
#  [8 5 4]
#  [6 0 7]]
# action= up , depth= 32336 , step cost= 5 , total_cost= 146591
#
# step 32337
# [[1 2 3]
#  [8 5 4]
#  [6 7 0]]
# action= left , depth= 32337 , step cost= 7 , total_cost= 146598
#
# step 32338
# [[1 2 3]
#  [8 5 0]
#  [6 7 4]]
# action= down , depth= 32338 , step cost= 4 , total_cost= 146602
#
# step 32339
# [[1 2 3]
#  [8 0 5]
#  [6 7 4]]
# action= right , depth= 32339 , step cost= 5 , total_cost= 146607
#
# step 32340
# [[1 2 3]
#  [8 7 5]
#  [6 0 4]]
# action= up , depth= 32340 , step cost= 7 , total_cost= 146614
#
# step 32341
# [[1 2 3]
#  [8 7 5]
#  [6 4 0]]
# action= left , depth= 32341 , step cost= 4 , total_cost= 146618
#
# step 32342
# [[1 2 3]
#  [8 7 0]
#  [6 4 5]]
# action= down , depth= 32342 , step cost= 5 , total_cost= 146623
#
# step 32343
# [[1 2 3]
#  [8 0 7]
#  [6 4 5]]
# action= right , depth= 32343 , step cost= 7 , total_cost= 146630
#
# step 32344
# [[1 2 3]
#  [0 8 7]
#  [6 4 5]]
# action= right , depth= 32344 , step cost= 8 , total_cost= 146638
#
# step 32345
# [[1 2 3]
#  [6 8 7]
#  [0 4 5]]
# action= up , depth= 32345 , step cost= 6 , total_cost= 146644
#
# step 32346
# [[1 2 3]
#  [6 8 7]
#  [4 0 5]]
# action= left , depth= 32346 , step cost= 4 , total_cost= 146648
#
# step 32347
# [[1 2 3]
#  [6 8 7]
#  [4 5 0]]
# action= left , depth= 32347 , step cost= 5 , total_cost= 146653
#
# step 32348
# [[1 2 3]
#  [6 8 0]
#  [4 5 7]]
# action= down , depth= 32348 , step cost= 7 , total_cost= 146660
#
# step 32349
# [[1 2 3]
#  [6 0 8]
#  [4 5 7]]
# action= right , depth= 32349 , step cost= 8 , total_cost= 146668
#
# step 32350
# [[1 2 3]
#  [6 5 8]
#  [4 0 7]]
# action= up , depth= 32350 , step cost= 5 , total_cost= 146673
#
# step 32351
# [[1 2 3]
#  [6 5 8]
#  [4 7 0]]
# action= left , depth= 32351 , step cost= 7 , total_cost= 146680
#
# step 32352
# [[1 2 3]
#  [6 5 0]
#  [4 7 8]]
# action= down , depth= 32352 , step cost= 8 , total_cost= 146688
#
# step 32353
# [[1 2 3]
#  [6 0 5]
#  [4 7 8]]
# action= right , depth= 32353 , step cost= 5 , total_cost= 146693
#
# step 32354
# [[1 2 3]
#  [6 7 5]
#  [4 0 8]]
# action= up , depth= 32354 , step cost= 7 , total_cost= 146700
#
# step 32355
# [[1 2 3]
#  [6 7 5]
#  [4 8 0]]
# action= left , depth= 32355 , step cost= 8 , total_cost= 146708
#
# step 32356
# [[1 2 3]
#  [6 7 0]
#  [4 8 5]]
# action= down , depth= 32356 , step cost= 5 , total_cost= 146713
#
# step 32357
# [[1 2 3]
#  [6 0 7]
#  [4 8 5]]
# action= right , depth= 32357 , step cost= 7 , total_cost= 146720
#
# step 32358
# [[1 2 3]
#  [0 6 7]
#  [4 8 5]]
# action= right , depth= 32358 , step cost= 6 , total_cost= 146726
#
# step 32359
# [[1 2 3]
#  [4 6 7]
#  [0 8 5]]
# action= up , depth= 32359 , step cost= 4 , total_cost= 146730
#
# step 32360
# [[1 2 3]
#  [4 6 7]
#  [8 0 5]]
# action= left , depth= 32360 , step cost= 8 , total_cost= 146738
#
# step 32361
# [[1 2 3]
#  [4 6 7]
#  [8 5 0]]
# action= left , depth= 32361 , step cost= 5 , total_cost= 146743
#
# step 32362
# [[1 2 3]
#  [4 6 0]
#  [8 5 7]]
# action= down , depth= 32362 , step cost= 7 , total_cost= 146750
#
# step 32363
# [[1 2 3]
#  [4 0 6]
#  [8 5 7]]
# action= right , depth= 32363 , step cost= 6 , total_cost= 146756
#
# step 32364
# [[1 2 3]
#  [4 5 6]
#  [8 0 7]]
# action= up , depth= 32364 , step cost= 5 , total_cost= 146761
#
# step 32365
# [[1 2 3]
#  [4 5 6]
#  [8 7 0]]
# action= left , depth= 32365 , step cost= 7 , total_cost= 146768
#
# step 32366
# [[1 2 3]
#  [4 5 0]
#  [8 7 6]]
# action= down , depth= 32366 , step cost= 6 , total_cost= 146774
#
# step 32367
# [[1 2 3]
#  [4 0 5]
#  [8 7 6]]
# action= right , depth= 32367 , step cost= 5 , total_cost= 146779
#
# step 32368
# [[1 2 3]
#  [0 4 5]
#  [8 7 6]]
# action= right , depth= 32368 , step cost= 4 , total_cost= 146783
#
# step 32369
# [[1 2 3]
#  [8 4 5]
#  [0 7 6]]
# action= up , depth= 32369 , step cost= 8 , total_cost= 146791
#
# step 32370
# [[1 2 3]
#  [8 4 5]
#  [7 0 6]]
# action= left , depth= 32370 , step cost= 7 , total_cost= 146798
#
# step 32371
# [[1 2 3]
#  [8 4 5]
#  [7 6 0]]
# action= left , depth= 32371 , step cost= 6 , total_cost= 146804
#
# step 32372
# [[1 2 3]
#  [8 4 0]
#  [7 6 5]]
# action= down , depth= 32372 , step cost= 5 , total_cost= 146809
#
# step 32373
# [[1 2 3]
#  [8 0 4]
#  [7 6 5]]
# action= right , depth= 32373 , step cost= 4 , total_cost= 146813
#
# Time performance: 32691 nodes popped off the pile.
# Space performance: 25201 nodes in the pile at its max.
# Time spent: 124.99s
# True

# %%
root_node.best_first_search(goal_etat)
# Out:
# step 0
# [[2 8 3]
#  [1 6 4]
#  [7 0 5]]
# action= None , depth= 0 , step cost= 0 , total_cost= 0
#
# step 1
# [[2 8 3]
#  [1 0 4]
#  [7 6 5]]
# action= down , depth= 1 , step cost= 6 , total_cost= 8
#
# step 2
# [[2 0 3]
#  [1 8 4]
#  [7 6 5]]
# action= down , depth= 2 , step cost= 8 , total_cost= 17
#
# step 3
# [[0 2 3]
#  [1 8 4]
#  [7 6 5]]
# action= right , depth= 3 , step cost= 2 , total_cost= 18
#
# step 4
# [[1 2 3]
#  [0 8 4]
#  [7 6 5]]
# action= up , depth= 4 , step cost= 1 , total_cost= 18
#
# step 5
# [[1 2 3]
#  [8 0 4]
#  [7 6 5]]
# action= left , depth= 5 , step cost= 8 , total_cost= 25
#
# Time performance: 6 nodes popped off the filee.
# Space performance: 7 nodes in the filee at its max.
# Time spent: 0.01s
# True

# %%
root_node.a_star_search(goal_etat,heuristic_function = 'num_misplaced')
